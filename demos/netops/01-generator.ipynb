# %% [markdown]
# # Generate simulated infrastructure telemetry

# %%
# Install requiered packages if needed (only once)
# !pip install pytimeparse
# !pip install -i https://test.pypi.org/simple/ v3io-generator --upgrade
# !pip install faker
# !pip install pyarrow --upgrade
# Out:
# Requirement already satisfied: pytimeparse in /User/.pythonlibs/lib/python3.6/site-packages (1.1.8)
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already up-to-date: v3io-generator in /User/.pythonlibs/lib/python3.6/site-packages (0.0.27.dev0)
# Requirement already satisfied: faker in /User/.pythonlibs/lib/python3.6/site-packages (1.0.4)
# Requirement already satisfied: six>=1.10 in /conda/lib/python3.6/site-packages (from faker) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.4 in /conda/lib/python3.6/site-packages (from faker) (2.8.0)
# Requirement already satisfied: text-unidecode==1.2 in /User/.pythonlibs/lib/python3.6/site-packages (from faker) (1.2)
# Requirement already up-to-date: pyarrow in /User/.pythonlibs/lib/python3.6/site-packages (0.12.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in /conda/lib/python3.6/site-packages (from pyarrow) (1.16.1)
# Requirement already satisfied, skipping upgrade: six>=1.0.0 in /conda/lib/python3.6/site-packages (from pyarrow) (1.12.0)

# %%
import os
import time
import yaml
import pandas as pd
import datetime
import itertools

# DB Connection
import v3io_frames as v3f

# Data generator
from v3io_generator import metrics_generator, deployment_generator

# %% [markdown]
# General definitions

# %%
# %env SAVE_TO_KV = True                 
# %env DEPLOYMENT_TABLE = netops_devices
# Out:
# env: SAVE_TO_KV=True
# env: DEPLOYMENT_TABLE=netops_devices

# %% [markdown]
# ## Create Metadata
# the following section will create a list of devices which are scattered in multiple datacenters

# %%
def _create_deployment():
    print('creating deployment')
    # Create meta-data factory
    dep_gen = deployment_generator.deployment_generator()
    faker=dep_gen.get_faker()

    # Design meta-data
    dep_gen.add_level(name='company',number=2,level_type=faker.company)
    dep_gen.add_level('data_center',number=2,level_type=faker.street_name)
    dep_gen.add_level('device',number=2,level_type=faker.msisdn)

    # Create meta-data
    deployment_df = dep_gen.generate_deployment()
    return deployment_df

# %%
def _is_deployment_exist(path):
    # Checking shared path for the devices table
    return os.path.exists(f'/v3io/bigdata/{path}')

# %%
def _get_deployment_from_kv(path):
    print(f'Retrieving deployment from {path}')
    # Read the devices table from our KV store
    deployment_df = client.read(backend='kv', table=path)
    
    # Reset index to column
    deployment_df.index.name = 'device'
    deployment_df = deployment_df.reset_index()
    return deployment_df

# %%
def _save_deployment_to_kv(path, df, client=v3f.Client('framesd:8081')):
    # Save deployment to our KV store
    client.write(backend='kv', table='netops_devices',dfs=df, index_cols=['device'])

# %%
def get_or_create_deployment(path, save_to_cloud=False, client=v3f.Client('framesd:8081')):
    if _is_deployment_exist(path):
        # Get deployment from KV
        deployment_df = _get_deployment_from_kv(path)
    else:
        # Create deployment
        deployment_df = _create_deployment()
        
        if save_to_cloud:
            _save_deployment_to_kv(path, deployment_df, client)

    return deployment_df

# %%
# Create our DB client
client = v3f.Client('framesd:8081')

# %%
deployment_df = get_or_create_deployment(os.environ['DEPLOYMENT_TABLE'], os.environ['SAVE_TO_KV'])
deployment_df
# Out:
# Retrieving deployment from netops_devices
#           device          company         data_center
# 0  0063085034865  Henderson-Lopez      Spencer_Greens
# 1  0236137499649  Henderson-Lopez        Rogers_Route
# 2  2190949003307     Kelly-Arroyo  Mclaughlin_Gateway
# 3  3440493824847     Kelly-Arroyo     Nicholas_Courts
# 4  3669819894699     Kelly-Arroyo     Nicholas_Courts
# 5  9909774422784  Henderson-Lopez      Spencer_Greens
# 6  7124057837347  Henderson-Lopez        Rogers_Route
# 7  5804822255480     Kelly-Arroyo  Mclaughlin_Gateway

# %% [markdown]
# Read from our KV to make sure we have backup

# %%
# verify the table is written 
client.read(backend='kv', table='netops_devices')
# Out:
#                        company         data_center
# __name
# 3440493824847     Kelly-Arroyo     Nicholas_Courts
# 3669819894699     Kelly-Arroyo     Nicholas_Courts
# 9909774422784  Henderson-Lopez      Spencer_Greens
# 7124057837347  Henderson-Lopez        Rogers_Route
# 5804822255480     Kelly-Arroyo  Mclaughlin_Gateway
# 0236137499649  Henderson-Lopez        Rogers_Route
# 2190949003307     Kelly-Arroyo  Mclaughlin_Gateway
# 0063085034865  Henderson-Lopez      Spencer_Greens

# %% [markdown]
# ## Add initial values

# %%
deployment_df['cpu_utilization'] = 70
deployment_df['latency'] = 0
deployment_df['packet_loss'] = 0
deployment_df['throughput'] = 290
deployment_df.head()
# Out:
#           device          company         data_center  cpu_utilization  \
# 0  0063085034865  Henderson-Lopez      Spencer_Greens               70
# 1  0236137499649  Henderson-Lopez        Rogers_Route               70
# 2  2190949003307     Kelly-Arroyo  Mclaughlin_Gateway               70
# 3  3440493824847     Kelly-Arroyo     Nicholas_Courts               70
# 4  3669819894699     Kelly-Arroyo     Nicholas_Courts               70
#
#    latency  packet_loss  throughput
# 0        0            0         290
# 1        0            0         290
# 2        0            0         290
# 3        0            0         290
# 4        0            0         290

# %% [markdown]
# ## Generate simulated metrics per device
# Metrics schema (describe simulated values) is read from `metrics_configuration.yaml`

# %%
# Load metrics configuration from YAML file
with open('metrics_configuration.yaml', 'r') as f:
    metrics_configuration = yaml.load(f)

# Create metrics generator based on YAML configuration
met_gen = metrics_generator.Generator_df(metrics_configuration, user_hierarchy=deployment_df, initial_timestamp=time.time())
metrics = met_gen.generate_range(start_time=datetime.datetime.now(),
                                 end_time=datetime.datetime.now()+datetime.timedelta(hours=1),
                                 as_df=True,
                                 as_iterator=True)

# %%
df = pd.concat(itertools.chain(metrics))
df.head(5)
# Out:
#                                                                              cpu_utilization  \
# timestamp                  company         data_center        device
# 2019-04-24 16:29:53.996772 Henderson-Lopez Spencer_Greens     0063085034865        80.300360
#                                            Rogers_Route       0236137499649        65.564479
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307        63.920317
#                                            Nicholas_Courts    3440493824847        53.639535
#                                                               3669819894699        74.254264
#
#                                                                              cpu_utilization_is_error  \
# timestamp                  company         data_center        device
# 2019-04-24 16:29:53.996772 Henderson-Lopez Spencer_Greens     0063085034865                     False
#                                            Rogers_Route       0236137499649                     False
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307                     False
#                                            Nicholas_Courts    3440493824847                     False
#                                                               3669819894699                     False
#
#                                                                               latency  \
# timestamp                  company         data_center        device
# 2019-04-24 16:29:53.996772 Henderson-Lopez Spencer_Greens     0063085034865  0.000000
#                                            Rogers_Route       0236137499649  3.117734
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307  2.819100
#                                            Nicholas_Courts    3440493824847  0.000000
#                                                               3669819894699  0.000000
#
#                                                                              latency_is_error  \
# timestamp                  company         data_center        device
# 2019-04-24 16:29:53.996772 Henderson-Lopez Spencer_Greens     0063085034865             False
#                                            Rogers_Route       0236137499649             False
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307             False
#                                            Nicholas_Courts    3440493824847             False
#                                                               3669819894699             False
#
#                                                                              packet_loss  \
# timestamp                  company         data_center        device
# 2019-04-24 16:29:53.996772 Henderson-Lopez Spencer_Greens     0063085034865     0.211627
#                                            Rogers_Route       0236137499649     0.000000
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307     1.572495
#                                            Nicholas_Courts    3440493824847     2.567153
#                                                               3669819894699     0.403987
#
#                                                                              packet_loss_is_error  \
# timestamp                  company         data_center        device
# 2019-04-24 16:29:53.996772 Henderson-Lopez Spencer_Greens     0063085034865                 False
#                                            Rogers_Route       0236137499649                 False
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307                 False
#                                            Nicholas_Courts    3440493824847                 False
#                                                               3669819894699                 False
#
#                                                                              throughput  \
# timestamp                  company         data_center        device
# 2019-04-24 16:29:53.996772 Henderson-Lopez Spencer_Greens     0063085034865  268.036926
#                                            Rogers_Route       0236137499649  238.819943
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307  227.147022
#                                            Nicholas_Courts    3440493824847  257.215786
#                                                               3669819894699  265.800801
#
#                                                                              throughput_is_error  \
# timestamp                  company         data_center        device
# 2019-04-24 16:29:53.996772 Henderson-Lopez Spencer_Greens     0063085034865                False
#                                            Rogers_Route       0236137499649                False
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307                False
#                                            Nicholas_Courts    3440493824847                False
#                                                               3669819894699                False
#
#                                                                              is_error
# timestamp                  company         data_center        device
# 2019-04-24 16:29:53.996772 Henderson-Lopez Spencer_Greens     0063085034865     False
#                                            Rogers_Route       0236137499649     False
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307     False
#                                            Nicholas_Courts    3440493824847     False
#                                                               3669819894699     False

# %% [markdown]
# ## Save to Iguazio Time-series Database

# %%
# uncomment the line below if you want to reset the TSDB table 
client.delete(backend='tsdb', table='netops_metrics_jupyter')

# %%
# create a new table, need to specify estimated sample rate
client.create(backend='tsdb', table='netops_metrics_jupyter', attrs={'rate': '1/m'})

# %%
# write the dataframe into the time-seried DB, note the company,data_center,device indexes are automatically converted to search optimized labels
client.write(backend='tsdb', table='netops_metrics_jupyter', dfs=df)

# %% [markdown]
# ## Verify that the data was written

# %%
client.read(backend='tsdb', query='select avg(cpu_utilization) as cpu_utilization, avg(latency) as latency, avg(packet_loss) as packet_loss, avg(throughput) as throughput from netops_metrics_jupyter group by company, data_center, device',
            start="now-1d", end='now+1d', multi_index=True, step='5m').head(10)
# Out:
#                                                                 cpu_utilization  \
# time                company         data_center  device
# 2019-04-24 16:21:13 Henderson-Lopez Rogers_Route 7124057837347        70.885992
# 2019-04-24 16:26:13 Henderson-Lopez Rogers_Route 7124057837347        81.921424
# 2019-04-24 16:31:13 Henderson-Lopez Rogers_Route 7124057837347        79.872988
# 2019-04-24 16:36:13 Henderson-Lopez Rogers_Route 7124057837347        72.426217
# 2019-04-24 16:41:13 Henderson-Lopez Rogers_Route 7124057837347        84.985113
# 2019-04-24 16:46:13 Henderson-Lopez Rogers_Route 7124057837347        69.994465
# 2019-04-24 16:51:13 Henderson-Lopez Rogers_Route 7124057837347        72.876036
# 2019-04-24 16:56:13 Henderson-Lopez Rogers_Route 7124057837347        69.033523
# 2019-04-24 17:01:13 Henderson-Lopez Rogers_Route 7124057837347        70.975776
# 2019-04-24 17:06:13 Henderson-Lopez Rogers_Route 7124057837347        69.775006
#
#                                                                   latency  \
# time                company         data_center  device
# 2019-04-24 16:21:13 Henderson-Lopez Rogers_Route 7124057837347   2.017412
# 2019-04-24 16:26:13 Henderson-Lopez Rogers_Route 7124057837347  35.154002
# 2019-04-24 16:31:13 Henderson-Lopez Rogers_Route 7124057837347  25.377096
# 2019-04-24 16:36:13 Henderson-Lopez Rogers_Route 7124057837347   7.671809
# 2019-04-24 16:41:13 Henderson-Lopez Rogers_Route 7124057837347  47.198010
# 2019-04-24 16:46:13 Henderson-Lopez Rogers_Route 7124057837347   1.745857
# 2019-04-24 16:51:13 Henderson-Lopez Rogers_Route 7124057837347   1.504754
# 2019-04-24 16:56:13 Henderson-Lopez Rogers_Route 7124057837347   2.238023
# 2019-04-24 17:01:13 Henderson-Lopez Rogers_Route 7124057837347   2.280567
# 2019-04-24 17:06:13 Henderson-Lopez Rogers_Route 7124057837347   2.047805
#
#                                                                 packet_loss  \
# time                company         data_center  device
# 2019-04-24 16:21:13 Henderson-Lopez Rogers_Route 7124057837347     0.967461
# 2019-04-24 16:26:13 Henderson-Lopez Rogers_Route 7124057837347     9.659135
# 2019-04-24 16:31:13 Henderson-Lopez Rogers_Route 7124057837347    12.417467
# 2019-04-24 16:36:13 Henderson-Lopez Rogers_Route 7124057837347     0.697650
# 2019-04-24 16:41:13 Henderson-Lopez Rogers_Route 7124057837347    21.325391
# 2019-04-24 16:46:13 Henderson-Lopez Rogers_Route 7124057837347     0.543987
# 2019-04-24 16:51:13 Henderson-Lopez Rogers_Route 7124057837347     0.672011
# 2019-04-24 16:56:13 Henderson-Lopez Rogers_Route 7124057837347     0.733741
# 2019-04-24 17:01:13 Henderson-Lopez Rogers_Route 7124057837347     0.888610
# 2019-04-24 17:06:13 Henderson-Lopez Rogers_Route 7124057837347     0.845098
#
#                                                                 throughput
# time                company         data_center  device
# 2019-04-24 16:21:13 Henderson-Lopez Rogers_Route 7124057837347  252.622477
# 2019-04-24 16:26:13 Henderson-Lopez Rogers_Route 7124057837347  212.575115
# 2019-04-24 16:31:13 Henderson-Lopez Rogers_Route 7124057837347  188.326686
# 2019-04-24 16:36:13 Henderson-Lopez Rogers_Route 7124057837347  251.799112
# 2019-04-24 16:41:13 Henderson-Lopez Rogers_Route 7124057837347  141.247529
# 2019-04-24 16:46:13 Henderson-Lopez Rogers_Route 7124057837347  253.486610
# 2019-04-24 16:51:13 Henderson-Lopez Rogers_Route 7124057837347  253.601863
# 2019-04-24 16:56:13 Henderson-Lopez Rogers_Route 7124057837347  250.953048
# 2019-04-24 17:01:13 Henderson-Lopez Rogers_Route 7124057837347  244.832079
# 2019-04-24 17:06:13 Henderson-Lopez Rogers_Route 7124057837347  248.655060

# %% [markdown]
# ### Save the generated dataset to parquet for future reproducability

# %%
# craete directory if doesnt exist 
# !mkdir data
# Out:
# mkdir: cannot create directory 'data': File exists

# %%
import pyarrow as pa
from pyarrow import parquet as pq

# %%
#write the dataframe into a parquet (on iguazio file system)
version = '1.0'
filepath = 'data/netops_metrics.v{}.parquet'.format(version)
pq.write_table(pa.Table.from_pandas(df), filepath)

# %% [markdown]
# ### Reading the data from parquet into the time-series DB
# if we want to reproduce the same results we can rebuild the TSDB from the saved parquet file

# %%
# uncomment the line below if you want to reset the TSDB table 
client.delete(backend='tsdb', table='netops_metrics_jupyter')
client.create(backend='tsdb', table='netops_metrics_jupyter', attrs={'rate': '1/m'})

# %%
# read the parquet into memory and print the head 
pqdf = pq.read_table(filepath).to_pandas()
pqdf.head()
# Out:
#                                                                              cpu_utilization  \
# timestamp                  company         data_center        device
# 2019-04-24 16:24:57.639091 Henderson-Lopez Spencer_Greens     0063085034865        76.223322
#                                            Rogers_Route       0236137499649        95.175780
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307        70.947110
#                                            Nicholas_Courts    3440493824847        89.953635
#                                                               3669819894699        71.813940
#
#                                                                              cpu_utilization_is_error  \
# timestamp                  company         data_center        device
# 2019-04-24 16:24:57.639091 Henderson-Lopez Spencer_Greens     0063085034865                     False
#                                            Rogers_Route       0236137499649                     False
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307                     False
#                                            Nicholas_Courts    3440493824847                     False
#                                                               3669819894699                     False
#
#                                                                               latency  \
# timestamp                  company         data_center        device
# 2019-04-24 16:24:57.639091 Henderson-Lopez Spencer_Greens     0063085034865  4.801430
#                                            Rogers_Route       0236137499649  0.000000
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307  1.409136
#                                            Nicholas_Courts    3440493824847  5.472598
#                                                               3669819894699  5.022275
#
#                                                                              latency_is_error  \
# timestamp                  company         data_center        device
# 2019-04-24 16:24:57.639091 Henderson-Lopez Spencer_Greens     0063085034865             False
#                                            Rogers_Route       0236137499649             False
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307             False
#                                            Nicholas_Courts    3440493824847             False
#                                                               3669819894699             False
#
#                                                                              packet_loss  \
# timestamp                  company         data_center        device
# 2019-04-24 16:24:57.639091 Henderson-Lopez Spencer_Greens     0063085034865     0.000000
#                                            Rogers_Route       0236137499649     1.699464
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307     0.000000
#                                            Nicholas_Courts    3440493824847     0.000000
#                                                               3669819894699     1.617140
#
#                                                                              packet_loss_is_error  \
# timestamp                  company         data_center        device
# 2019-04-24 16:24:57.639091 Henderson-Lopez Spencer_Greens     0063085034865                 False
#                                            Rogers_Route       0236137499649                 False
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307                 False
#                                            Nicholas_Courts    3440493824847                 False
#                                                               3669819894699                 False
#
#                                                                              throughput  \
# timestamp                  company         data_center        device
# 2019-04-24 16:24:57.639091 Henderson-Lopez Spencer_Greens     0063085034865  283.648942
#                                            Rogers_Route       0236137499649  265.224289
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307  274.725084
#                                            Nicholas_Courts    3440493824847  263.175821
#                                                               3669819894699  243.377758
#
#                                                                              throughput_is_error  \
# timestamp                  company         data_center        device
# 2019-04-24 16:24:57.639091 Henderson-Lopez Spencer_Greens     0063085034865                False
#                                            Rogers_Route       0236137499649                False
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307                False
#                                            Nicholas_Courts    3440493824847                False
#                                                               3669819894699                False
#
#                                                                              is_error
# timestamp                  company         data_center        device
# 2019-04-24 16:24:57.639091 Henderson-Lopez Spencer_Greens     0063085034865     False
#                                            Rogers_Route       0236137499649     False
#                            Kelly-Arroyo    Mclaughlin_Gateway 2190949003307     False
#                                            Nicholas_Courts    3440493824847     False
#                                                               3669819894699     False

# %%
# write the dataframe into the time-seried DB, uncomment the line below
client.write(backend='tsdb', table='netops_metrics_jupyter', dfs=pqdf)

# %%
# verify the table is written 
client.read(backend='tsdb', query='select avg(cpu_utilization) as cpu_utilization_avg, avg(latency) as latency_avg, avg(packet_loss) as packet_loss_avg, avg(throughput) as throughput_avg from netops_metrics_jupyter group by company, data_center, device',
            start="now-1d", end='now+1d', multi_index=True, step='5m').head(10)
# Out:
#                                                                 cpu_utilization  \
# time                company      data_center     device
# 2019-04-24 16:24:28 Kelly-Arroyo Nicholas_Courts 3669819894699        70.849387
# 2019-04-24 16:29:28 Kelly-Arroyo Nicholas_Courts 3669819894699        84.817562
# 2019-04-24 16:34:28 Kelly-Arroyo Nicholas_Courts 3669819894699        70.633385
# 2019-04-24 16:39:28 Kelly-Arroyo Nicholas_Courts 3669819894699        83.232115
# 2019-04-24 16:44:28 Kelly-Arroyo Nicholas_Courts 3669819894699        71.467319
# 2019-04-24 16:49:28 Kelly-Arroyo Nicholas_Courts 3669819894699        82.285018
# 2019-04-24 16:54:28 Kelly-Arroyo Nicholas_Courts 3669819894699        75.989181
# 2019-04-24 16:59:28 Kelly-Arroyo Nicholas_Courts 3669819894699        69.636836
# 2019-04-24 17:04:28 Kelly-Arroyo Nicholas_Courts 3669819894699        69.289693
# 2019-04-24 17:09:28 Kelly-Arroyo Nicholas_Courts 3669819894699        83.253099
#
#                                                                   latency  \
# time                company      data_center     device
# 2019-04-24 16:24:28 Kelly-Arroyo Nicholas_Courts 3669819894699   2.147264
# 2019-04-24 16:29:28 Kelly-Arroyo Nicholas_Courts 3669819894699  46.930369
# 2019-04-24 16:34:28 Kelly-Arroyo Nicholas_Courts 3669819894699   1.493488
# 2019-04-24 16:39:28 Kelly-Arroyo Nicholas_Courts 3669819894699  47.085941
# 2019-04-24 16:44:28 Kelly-Arroyo Nicholas_Courts 3669819894699   5.493702
# 2019-04-24 16:49:28 Kelly-Arroyo Nicholas_Courts 3669819894699  28.064059
# 2019-04-24 16:54:28 Kelly-Arroyo Nicholas_Courts 3669819894699  21.781918
# 2019-04-24 16:59:28 Kelly-Arroyo Nicholas_Courts 3669819894699   2.377856
# 2019-04-24 17:04:28 Kelly-Arroyo Nicholas_Courts 3669819894699   1.585281
# 2019-04-24 17:09:28 Kelly-Arroyo Nicholas_Courts 3669819894699  43.376949
#
#                                                                 packet_loss  \
# time                company      data_center     device
# 2019-04-24 16:24:28 Kelly-Arroyo Nicholas_Courts 3669819894699     0.677893
# 2019-04-24 16:29:28 Kelly-Arroyo Nicholas_Courts 3669819894699    22.344594
# 2019-04-24 16:34:28 Kelly-Arroyo Nicholas_Courts 3669819894699     0.884610
# 2019-04-24 16:39:28 Kelly-Arroyo Nicholas_Courts 3669819894699    21.721325
# 2019-04-24 16:44:28 Kelly-Arroyo Nicholas_Courts 3669819894699     2.827508
# 2019-04-24 16:49:28 Kelly-Arroyo Nicholas_Courts 3669819894699    11.715909
# 2019-04-24 16:54:28 Kelly-Arroyo Nicholas_Courts 3669819894699    10.659431
# 2019-04-24 16:59:28 Kelly-Arroyo Nicholas_Courts 3669819894699     0.606287
# 2019-04-24 17:04:28 Kelly-Arroyo Nicholas_Courts 3669819894699     0.866739
# 2019-04-24 17:09:28 Kelly-Arroyo Nicholas_Courts 3669819894699    20.534600
#
#                                                                 throughput
# time                company      data_center     device
# 2019-04-24 16:24:28 Kelly-Arroyo Nicholas_Courts 3669819894699  246.597086
# 2019-04-24 16:29:28 Kelly-Arroyo Nicholas_Courts 3669819894699  149.586233
# 2019-04-24 16:34:28 Kelly-Arroyo Nicholas_Courts 3669819894699  251.194946
# 2019-04-24 16:39:28 Kelly-Arroyo Nicholas_Courts 3669819894699  176.920127
# 2019-04-24 16:44:28 Kelly-Arroyo Nicholas_Courts 3669819894699  242.738542
# 2019-04-24 16:49:28 Kelly-Arroyo Nicholas_Courts 3669819894699  201.513149
# 2019-04-24 16:54:28 Kelly-Arroyo Nicholas_Courts 3669819894699  200.802553
# 2019-04-24 16:59:28 Kelly-Arroyo Nicholas_Courts 3669819894699  245.767407
# 2019-04-24 17:04:28 Kelly-Arroyo Nicholas_Courts 3669819894699  238.516940
# 2019-04-24 17:09:28 Kelly-Arroyo Nicholas_Courts 3669819894699  150.155566

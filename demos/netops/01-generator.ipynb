# %% [markdown]
# # Generate simulated infrastructure telemetry

# %%
# Install requiered packages if needed (only once)
# !pip install pytimeparse
# !pip install -i https://test.pypi.org/simple/ v3io-generator --upgrade
# !pip install faker
# !pip install pyarrow --upgrade
# Out:
# Requirement already satisfied: pytimeparse in /User/.pythonlibs/lib/python3.6/site-packages (1.1.8)
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already up-to-date: v3io-generator in /User/.pythonlibs/lib/python3.6/site-packages (0.0.27.dev0)
# Requirement already satisfied: faker in /User/.pythonlibs/lib/python3.6/site-packages (1.0.7)
# Requirement already satisfied: text-unidecode==1.2 in /User/.pythonlibs/lib/python3.6/site-packages (from faker) (1.2)
# Requirement already satisfied: six>=1.10 in /conda/lib/python3.6/site-packages (from faker) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.4 in /conda/lib/python3.6/site-packages (from faker) (2.8.0)
# Requirement already up-to-date: pyarrow in /User/.pythonlibs/lib/python3.6/site-packages (0.13.0)
# Requirement already satisfied, skipping upgrade: six>=1.0.0 in /conda/lib/python3.6/site-packages (from pyarrow) (1.12.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in /conda/lib/python3.6/site-packages (from pyarrow) (1.16.4)

# %%
import os
import time
import yaml
import pandas as pd
import datetime
import itertools

# DB Connection
import v3io_frames as v3f

# Data generator
from v3io_generator import metrics_generator, deployment_generator

# %% [markdown]
# General definitions

# %%
# %env SAVE_TO_KV = True                 
# %env DEPLOYMENT_TABLE = netops_devices
# Out:
# env: SAVE_TO_KV=True
# env: DEPLOYMENT_TABLE=netops_devices

# %% [markdown]
# ## Create Metadata
# the following section will create a list of devices which are scattered in multiple datacenters

# %%
def _create_deployment():
    print('creating deployment')
    # Create meta-data factory
    dep_gen = deployment_generator.deployment_generator()
    faker=dep_gen.get_faker()

    # Design meta-data
    dep_gen.add_level(name='company',number=2,level_type=faker.company)
    dep_gen.add_level('data_center',number=2,level_type=faker.street_name)
    dep_gen.add_level('device',number=2,level_type=faker.msisdn)

    # Create meta-data
    deployment_df = dep_gen.generate_deployment()
    return deployment_df

# %%
def _is_deployment_exist(path):
    # Checking shared path for the devices table
    return os.path.exists(f'/v3io/bigdata/{path}')

# %%
def _get_deployment_from_kv(path):
    print(f'Retrieving deployment from {path}')
    # Read the devices table from our KV store
    deployment_df = client.read(backend='kv', table=path)
    
    # Reset index to column
    deployment_df.index.name = 'device'
    deployment_df = deployment_df.reset_index()
    return deployment_df

# %%
def _save_deployment_to_kv(path, df, client=v3f.Client('framesd:8081')):
    # Save deployment to our KV store
    client.write(backend='kv', table='netops_devices',dfs=df, index_cols=['device'])

# %%
def get_or_create_deployment(path, save_to_cloud=False, client=v3f.Client('framesd:8081')):
    if _is_deployment_exist(path):
        # Get deployment from KV
        deployment_df = _get_deployment_from_kv(path)
    else:
        # Create deployment
        deployment_df = _create_deployment()
        
        if save_to_cloud:
            _save_deployment_to_kv(path, deployment_df, client)

    return deployment_df

# %%
# Create our DB client
client = v3f.Client('framesd:8081')

# %%
deployment_df = get_or_create_deployment(os.environ['DEPLOYMENT_TABLE'], os.environ['SAVE_TO_KV'])
deployment_df
# Out:
# Retrieving deployment from netops_devices
#           device                     company        data_center
# 0  1416256267840          Washington-Lambert      Tamara_Greens
# 1  9909218583192  Ortega__Nelson_and_Parrish  Gallagher_Springs
# 2  9999032632997  Ortega__Nelson_and_Parrish          Chen_Rest
# 3  0243526550889          Washington-Lambert       Nicole_Trail
# 4  2588823083436  Ortega__Nelson_and_Parrish          Chen_Rest
# 5  6842603445464  Ortega__Nelson_and_Parrish  Gallagher_Springs
# 6  9025508674926          Washington-Lambert      Tamara_Greens
# 7  5079628775825          Washington-Lambert       Nicole_Trail

# %% [markdown]
# Read from our KV to make sure we have backup

# %%
# verify the table is written 
client.read(backend='kv', table='netops_devices')
# Out:
#                                   company        data_center
# device
# 6842603445464  Ortega__Nelson_and_Parrish  Gallagher_Springs
# 1416256267840          Washington-Lambert      Tamara_Greens
# 9909218583192  Ortega__Nelson_and_Parrish  Gallagher_Springs
# 9999032632997  Ortega__Nelson_and_Parrish          Chen_Rest
# 0243526550889          Washington-Lambert       Nicole_Trail
# 2588823083436  Ortega__Nelson_and_Parrish          Chen_Rest
# 9025508674926          Washington-Lambert      Tamara_Greens
# 5079628775825          Washington-Lambert       Nicole_Trail

# %% [markdown]
# ## Add initial values

# %%
deployment_df['cpu_utilization'] = 70
deployment_df['latency'] = 0
deployment_df['packet_loss'] = 0
deployment_df['throughput'] = 290
deployment_df.head()
# Out:
#           device                     company        data_center  \
# 0  1416256267840          Washington-Lambert      Tamara_Greens
# 1  9909218583192  Ortega__Nelson_and_Parrish  Gallagher_Springs
# 2  9999032632997  Ortega__Nelson_and_Parrish          Chen_Rest
# 3  0243526550889          Washington-Lambert       Nicole_Trail
# 4  2588823083436  Ortega__Nelson_and_Parrish          Chen_Rest
#
#    cpu_utilization  latency  packet_loss  throughput
# 0               70        0            0         290
# 1               70        0            0         290
# 2               70        0            0         290
# 3               70        0            0         290
# 4               70        0            0         290

# %% [markdown]
# ## Generate simulated metrics per device
# Metrics schema (describe simulated values) is read from `metrics_configuration.yaml`

# %%
# Load metrics configuration from YAML file
with open('configurations/metrics_configuration.yaml', 'r') as f:
    metrics_configuration = yaml.load(f)

# Create metrics generator based on YAML configuration
met_gen = metrics_generator.Generator_df(metrics_configuration, user_hierarchy=deployment_df, initial_timestamp=time.time())
metrics = met_gen.generate_range(start_time=datetime.datetime.now(),
                                 end_time=datetime.datetime.now()+datetime.timedelta(hours=1),
                                 as_df=True,
                                 as_iterator=True)
# Out:
# /conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df = pd.concat(itertools.chain(metrics))
df.head(5)
# Out:
#                                                                                        cpu_utilization  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840        68.340178
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192        79.825575
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997        74.625916
#                            Nicole_Trail      Washington-Lambert         0243526550889        64.806974
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436        57.561720
#
#                                                                                        cpu_utilization_is_error  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840                     False
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192                     False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997                     False
#                            Nicole_Trail      Washington-Lambert         0243526550889                     False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436                     False
#
#                                                                                         latency  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840  4.736444
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192  5.369881
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997  0.000000
#                            Nicole_Trail      Washington-Lambert         0243526550889  0.000000
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436  2.732402
#
#                                                                                        latency_is_error  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840             False
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192             False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997             False
#                            Nicole_Trail      Washington-Lambert         0243526550889             False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436             False
#
#                                                                                        packet_loss  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840     3.086756
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192     0.000000
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997     0.810500
#                            Nicole_Trail      Washington-Lambert         0243526550889     1.177091
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436     3.374598
#
#                                                                                        packet_loss_is_error  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840                 False
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192                 False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997                 False
#                            Nicole_Trail      Washington-Lambert         0243526550889                 False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436                 False
#
#                                                                                        throughput  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840  255.270204
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192  244.680344
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997  229.439649
#                            Nicole_Trail      Washington-Lambert         0243526550889  240.797342
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436  238.602076
#
#                                                                                        throughput_is_error  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840                False
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192                False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997                False
#                            Nicole_Trail      Washington-Lambert         0243526550889                False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436                False
#
#                                                                                        is_error
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840     False
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192     False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997     False
#                            Nicole_Trail      Washington-Lambert         0243526550889     False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436     False

# %% [markdown]
# ## Save to Iguazio Time-series Database

# %%
# uncomment the line below if you want to reset the TSDB table 
client.delete(backend='tsdb', table='netops_metrics_jupyter')

# %%
# create a new table, need to specify estimated sample rate
client.create(backend='tsdb', table='netops_metrics_jupyter', attrs={'rate': '1/m'})

# %%
# write the dataframe into the time-seried DB, note the company,data_center,device indexes are automatically converted to search optimized labels
client.write(backend='tsdb', table='netops_metrics_jupyter', dfs=df)

# %% [markdown]
# ## Verify that the data was written

# %%
client.read(backend='tsdb', query='select avg(cpu_utilization), avg(latency) , avg(packet_loss) , avg(throughput)  from netops_metrics_jupyter group by company, data_center, device',
            start="now-1d", end='now+1d', multi_index=True, step='5m').head(10)
# Out:
#                                                                           avg(cpu_utilization)  \
# time                company                    data_center device
# 2019-06-17 14:34:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             68.078416
# 2019-06-17 14:39:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             68.533801
# 2019-06-17 14:44:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             70.377798
# 2019-06-17 14:49:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             87.306579
# 2019-06-17 14:54:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             67.573655
# 2019-06-17 14:59:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             69.896618
# 2019-06-17 15:04:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             69.737311
# 2019-06-17 15:09:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             72.079085
# 2019-06-17 15:14:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             72.180327
# 2019-06-17 15:19:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             84.834458
#
#                                                                           avg(latency)  \
# time                company                    data_center device
# 2019-06-17 14:34:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      1.423847
# 2019-06-17 14:39:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      2.367653
# 2019-06-17 14:44:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      2.096841
# 2019-06-17 14:49:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997     47.314863
# 2019-06-17 14:54:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      2.729573
# 2019-06-17 14:59:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      1.819913
# 2019-06-17 15:04:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      2.025129
# 2019-06-17 15:09:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      1.606980
# 2019-06-17 15:14:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      1.475628
# 2019-06-17 15:19:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997     45.076050
#
#                                                                           avg(packet_loss)  \
# time                company                    data_center device
# 2019-06-17 14:34:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.897193
# 2019-06-17 14:39:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.844910
# 2019-06-17 14:44:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.455499
# 2019-06-17 14:49:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997         21.452884
# 2019-06-17 14:54:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.856969
# 2019-06-17 14:59:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.666666
# 2019-06-17 15:04:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.734578
# 2019-06-17 15:09:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.915787
# 2019-06-17 15:14:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          1.772953
# 2019-06-17 15:19:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997         25.396808
#
#                                                                           avg(throughput)
# time                company                    data_center device
# 2019-06-17 14:34:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       244.903743
# 2019-06-17 14:39:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       246.186991
# 2019-06-17 14:44:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       252.081668
# 2019-06-17 14:49:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       159.983865
# 2019-06-17 14:54:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       250.914966
# 2019-06-17 14:59:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       251.590818
# 2019-06-17 15:04:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       249.674377
# 2019-06-17 15:09:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       255.811956
# 2019-06-17 15:14:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       252.170768
# 2019-06-17 15:19:46 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       166.740806

# %% [markdown]
# ### Save the generated dataset to parquet for future reproducability

# %%
# craete directory if doesnt exist 
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
import pyarrow as pa
from pyarrow import parquet as pq

# %%
#write the dataframe into a parquet (on iguazio file system)
version = '1.0'
filepath = 'data/netops_metrics.v{}.parquet'.format(version)
pq.write_table(pa.Table.from_pandas(df), filepath)

# %% [markdown]
# ### Reading the data from parquet into the time-series DB
# if we want to reproduce the same results we can rebuild the TSDB from the saved parquet file

# %%
# uncomment the line below if you want to reset the TSDB table 
client.delete(backend='tsdb', table='netops_metrics_jupyter')
client.create(backend='tsdb', table='netops_metrics_jupyter', attrs={'rate': '1/m'})

# %%
# read the parquet into memory and print the head 
pqdf = pq.read_table(filepath).to_pandas()
pqdf.head()
# Out:
#                                                                                        cpu_utilization  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840        68.340178
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192        79.825575
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997        74.625916
#                            Nicole_Trail      Washington-Lambert         0243526550889        64.806974
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436        57.561720
#
#                                                                                        cpu_utilization_is_error  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840                     False
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192                     False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997                     False
#                            Nicole_Trail      Washington-Lambert         0243526550889                     False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436                     False
#
#                                                                                         latency  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840  4.736444
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192  5.369881
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997  0.000000
#                            Nicole_Trail      Washington-Lambert         0243526550889  0.000000
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436  2.732402
#
#                                                                                        latency_is_error  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840             False
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192             False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997             False
#                            Nicole_Trail      Washington-Lambert         0243526550889             False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436             False
#
#                                                                                        packet_loss  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840     3.086756
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192     0.000000
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997     0.810500
#                            Nicole_Trail      Washington-Lambert         0243526550889     1.177091
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436     3.374598
#
#                                                                                        packet_loss_is_error  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840                 False
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192                 False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997                 False
#                            Nicole_Trail      Washington-Lambert         0243526550889                 False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436                 False
#
#                                                                                        throughput  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840  255.270204
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192  244.680344
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997  229.439649
#                            Nicole_Trail      Washington-Lambert         0243526550889  240.797342
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436  238.602076
#
#                                                                                        throughput_is_error  \
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840                False
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192                False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997                False
#                            Nicole_Trail      Washington-Lambert         0243526550889                False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436                False
#
#                                                                                        is_error
# timestamp                  data_center       company                    device
# 2019-06-17 14:39:24.404731 Tamara_Greens     Washington-Lambert         1416256267840     False
#                            Gallagher_Springs Ortega__Nelson_and_Parrish 9909218583192     False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 9999032632997     False
#                            Nicole_Trail      Washington-Lambert         0243526550889     False
#                            Chen_Rest         Ortega__Nelson_and_Parrish 2588823083436     False

# %%
# write the dataframe into the time-seried DB, uncomment the line below
client.write(backend='tsdb', table='netops_metrics_jupyter', dfs=pqdf)

# %%
# verify the table is written 
client.read(backend='tsdb', query='select avg(cpu_utilization) , avg(latency) , avg(packet_loss) , avg(throughput)  from netops_metrics_jupyter group by company, data_center, device',
            start="now-1d", end='now+1d', multi_index=True, step='5m').head(10)
# Out:
#                                                                           avg(cpu_utilization)  \
# time                company                    data_center device
# 2019-06-17 14:34:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             67.675289
# 2019-06-17 14:39:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             68.178614
# 2019-06-17 14:44:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             70.869440
# 2019-06-17 14:49:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             86.957390
# 2019-06-17 14:54:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             67.901543
# 2019-06-17 14:59:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             70.016103
# 2019-06-17 15:04:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             69.325575
# 2019-06-17 15:09:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             72.047269
# 2019-06-17 15:14:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             72.510986
# 2019-06-17 15:19:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997             85.081636
#
#                                                                           avg(latency)  \
# time                company                    data_center device
# 2019-06-17 14:34:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      1.139078
# 2019-06-17 14:39:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      2.367653
# 2019-06-17 14:44:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      2.096841
# 2019-06-17 14:49:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997     47.429515
# 2019-06-17 14:54:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      2.638625
# 2019-06-17 14:59:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      1.796209
# 2019-06-17 15:04:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      2.141810
# 2019-06-17 15:09:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      1.490299
# 2019-06-17 15:14:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997      1.475628
# 2019-06-17 15:19:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997     45.076050
#
#                                                                           avg(packet_loss)  \
# time                company                    data_center device
# 2019-06-17 14:34:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.797778
# 2019-06-17 14:39:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.857688
# 2019-06-17 14:44:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.440598
# 2019-06-17 14:49:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997         21.464396
# 2019-06-17 14:54:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.839577
# 2019-06-17 14:59:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.666666
# 2019-06-17 15:04:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.734578
# 2019-06-17 15:09:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          0.915787
# 2019-06-17 15:14:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997          1.772953
# 2019-06-17 15:19:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997         25.412336
#
#                                                                           avg(throughput)
# time                company                    data_center device
# 2019-06-17 14:34:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       239.154164
# 2019-06-17 14:39:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       246.453351
# 2019-06-17 14:44:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       253.142512
# 2019-06-17 14:49:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       159.796418
# 2019-06-17 14:54:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       249.824000
# 2019-06-17 14:59:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       252.405314
# 2019-06-17 15:04:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       249.794588
# 2019-06-17 15:09:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       255.727727
# 2019-06-17 15:14:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       251.612780
# 2019-06-17 15:19:54 Ortega__Nelson_and_Parrish Chen_Rest   9999032632997       166.853232

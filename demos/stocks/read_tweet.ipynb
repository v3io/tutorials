# %% [markdown]
# # Ingest Twitter Feed Data and Sentiments into iguazio Stream & Time-Series DB

# %% [markdown]
# ## Initialization
# install packages and set environment variables.<br>
# need to fill the following environment variables with real credentials.
#
# ```
#     V3IO_PASSWORD = <V3IO-Password>
#     V3IO_USER = <V3IO-Username>
#     V3IO_ADDRESS = <address of V3IO API end point>
#
#     # Twitter credentials
#     app_key = <..>
#     app_secret = <..>
#     oauth_token = <..>
#     oauth_token_secret = <..>
#
# ```
# > note: in nuclio environment variables and build dependencies are specified in the configuration tab, for notebooks they can be initialized from a file as implemented below.

# %%
# nuclio: ignore
# !pip install textblob
# !pip install twython

# %% [markdown]
# ### initialize nuclio emulation (this section will be ignored by nuclio nbconvert)

# %%
# nuclio: ignore
from nuclio import Context, Event
from v3io import env_fromfile
env_fromfile('tweet_env.txt')
context = Context()

# %% [markdown]
# ### Twitter stream handling class

# %%
from twython import TwythonStreamer
import json
import re
import v3io
import os
from textblob import TextBlob
import v3io_frames as v3f
import pandas as pd

oauth = {
    'app_key' : os.getenv('app_key'),
    'app_secret' : os.getenv('app_secret'),  
    'oauth_token' : os.getenv('oauth_token'), 
    'oauth_token_secret' : os.getenv('oauth_token_secret'),
}
lastText = ''

# initialize iguazio v3io APIs
v3 = v3io.v3io(os.getenv('V3IO_ADDRESS'),os.getenv('V3IO_USER'),os.getenv('V3IO_PASSWORD'), 'bigdata')
client = v3f.Client('v3io-framesd:8081', password=os.getenv('V3IO_PASSWORD'))

# Twitter stream handler  
class MyStreamer(TwythonStreamer):
    def __init__(self, context, name, **kw):
        self.name = name
        self.context = context
        TwythonStreamer.__init__(self, **kw)
        
    def start(self, cb, limit=10, **kw):
        self.cb = cb
        self.limit = limit
        self.statuses.filter(**kw)
        
    def on_success(self, data):
        if 'text' in data:
            record = {'text': data['text'], 
                      'user': '@'+data['user']['screen_name'],
                      'id': data['id'],
                      'created_at':data['created_at'],
                     }
            self.context.last_message = record
            if self.cb:
                self.cb(self.context, self.name, record)
                
        self.limit -= 1 
        if self.limit <= 0 :
            self.disconnect()

    def on_error(self, status_code, data):
        self.context.logger.error_with('Error in stream', status_code=status_code)

def process_event(context, name, record):
    clean = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", record['text']).split())
        
    # enrich the record with natural language metadata
    blob = TextBlob(clean)
    record['polarity'] = blob.sentiment.polarity
    record['subjectivity'] = blob.sentiment.subjectivity

    # Write the record into a iguazio straem
    context.logger.debug_with('writing data to Stream', record=record)
    resp = v3.putrecords('stock_stream', [json.dumps(record)])
        
    # Write data to iguazio Time-Series DB
    df = pd.DataFrame(index=[[pd.to_datetime(record['created_at'])],['GOOG']], columns=['sentiment'])
    df['sentiment'] = [float(blob.sentiment.polarity)]
    df.index.names=['time','symbol']
    client.write(backend='tsdb', table='stock_metrics',dfs=df)

# %% [markdown]
# ## Nuclio service initialization (init_context) and event handler implementation

# %%
import threading

def start_listener(context):
    stream = MyStreamer(context, 'GOOG', **oauth)
    stream.start(process_event, 200, track='@Google', lang='en')

def handler(context, event):
    return json.dumps(context.last_message)

def init_context(context):
    context.last_message = {}
    t = threading.Thread(target=start_listener, args=(context,))
    t.start()

# %% [markdown]
# ## Function invocation
# the following section simulates nuclio function initialization and invocation

# %%
# nuclio: ignore
init_context(context)
event = Event(body='')
# Out:
# 2018-12-17 19:53:20,524 nuclio (D) writing data to Stream {"record": {"text": "Hey you awesome people at @PeelPublicWorks @regionofpeel \nDo you know that if an URL is too long then you can short\u2026 https://t.co/e9gfGEBKX9", "user": "@NileshR_Shah", "id": 1074754410532741122, "created_at": "Mon Dec 17 19:53:14 +0000 2018", "polarity": 0.31666666666666665, "subjectivity": 0.5666666666666667}}
# 2018-12-17 19:53:20,550 nuclio (D) writing data to Stream {"record": {"text": "Hey you awesome people at @PeelPublicWorks @regionofpeel \nDo you know that if an URL is too long then you can short\u2026 https://t.co/e9gfGEBKX9", "user": "@NileshR_Shah", "id": 1074754410532741122, "created_at": "Mon Dec 17 19:53:14 +0000 2018", "polarity": 0.31666666666666665, "subjectivity": 0.5666666666666667}}
# 2018-12-17 19:53:29,024 nuclio (D) writing data to Stream {"record": {"text": "\u2018 CCIA (@Google\u2069 etc)..acknowledges that #Art13 will \u201cbenefit rightholders.\u201d ...[but] their messaging in the EU is\u2026 https://t.co/wHWXqR305m", "user": "@crispinhunt", "id": 1074754451288793088, "created_at": "Mon Dec 17 19:53:23 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:53:29,031 nuclio (D) writing data to Stream {"record": {"text": "\u2018 CCIA (@Google\u2069 etc)..acknowledges that #Art13 will \u201cbenefit rightholders.\u201d ...[but] their messaging in the EU is\u2026 https://t.co/wHWXqR305m", "user": "@crispinhunt", "id": 1074754451288793088, "created_at": "Mon Dec 17 19:53:23 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:53:35,415 nuclio (D) writing data to Stream {"record": {"text": "RT @BasedBasterd: As @Google's own CEO says that the Russians spent a measly $4,700.00 on the 2016 election.....you people have lost your m\u2026", "user": "@MargaretTrucks", "id": 1074754477264068610, "created_at": "Mon Dec 17 19:53:30 +0000 2018", "polarity": -0.022222222222222254, "subjectivity": 0.6555555555555556}}
# 2018-12-17 19:53:35,429 nuclio (D) writing data to Stream {"record": {"text": "RT @BasedBasterd: As @Google's own CEO says that the Russians spent a measly $4,700.00 on the 2016 election.....you people have lost your m\u2026", "user": "@MargaretTrucks", "id": 1074754477264068610, "created_at": "Mon Dec 17 19:53:30 +0000 2018", "polarity": -0.022222222222222254, "subjectivity": 0.6555555555555556}}
# 2018-12-17 19:53:39,157 nuclio (D) writing data to Stream {"record": {"text": ".@Google The Russian site listing hundreds of emails and passwords is still the first result when I AskJeeves it. What's up with that?", "user": "@Richie__Ryan", "id": 1074754493848395776, "created_at": "Mon Dec 17 19:53:33 +0000 2018", "polarity": 0.125, "subjectivity": 0.16666666666666666}}
# 2018-12-17 19:53:39,162 nuclio (D) writing data to Stream {"record": {"text": ".@Google The Russian site listing hundreds of emails and passwords is still the first result when I AskJeeves it. What's up with that?", "user": "@Richie__Ryan", "id": 1074754493848395776, "created_at": "Mon Dec 17 19:53:33 +0000 2018", "polarity": 0.125, "subjectivity": 0.16666666666666666}}
# 2018-12-17 19:53:43,243 nuclio (D) writing data to Stream {"record": {"text": "#Internacionales | @Google abri\u00f3 su primera oficina en Nueva York hace casi 20 a\u00f1os. El Gigante de la b\u00fasqueda en i\u2026 https://t.co/rb7obyzPjy", "user": "@UdlaChannelEc", "id": 1074754509904195588, "created_at": "Mon Dec 17 19:53:37 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:53:43,250 nuclio (D) writing data to Stream {"record": {"text": "#Internacionales | @Google abri\u00f3 su primera oficina en Nueva York hace casi 20 a\u00f1os. El Gigante de la b\u00fasqueda en i\u2026 https://t.co/rb7obyzPjy", "user": "@UdlaChannelEc", "id": 1074754509904195588, "created_at": "Mon Dec 17 19:53:37 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:53:47,642 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@drugshastommo", "id": 1074754529227358208, "created_at": "Mon Dec 17 19:53:42 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:53:47,659 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@drugshastommo", "id": 1074754529227358208, "created_at": "Mon Dec 17 19:53:42 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:53:52,837 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@manon_masnt", "id": 1074754551247441920, "created_at": "Mon Dec 17 19:53:47 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:53:52,849 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@manon_masnt", "id": 1074754551247441920, "created_at": "Mon Dec 17 19:53:47 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:54:00,608 nuclio (D) writing data to Stream {"record": {"text": "@Google when will you be offering home services in my area so I can leave #Verizon altogether.", "user": "@johanthemerican", "id": 1074754583925264384, "created_at": "Mon Dec 17 19:53:55 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:54:00,629 nuclio (D) writing data to Stream {"record": {"text": "@Google when will you be offering home services in my area so I can leave #Verizon altogether.", "user": "@johanthemerican", "id": 1074754583925264384, "created_at": "Mon Dec 17 19:53:55 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:54:12,042 nuclio (D) writing data to Stream {"record": {"text": "RT @BasedBasterd: As @Google's own CEO says that the Russians spent a measly $4,700.00 on the 2016 election.....you people have lost your m\u2026", "user": "@fightin2Bfree", "id": 1074754631161573382, "created_at": "Mon Dec 17 19:54:06 +0000 2018", "polarity": -0.022222222222222254, "subjectivity": 0.6555555555555556}}
# 2018-12-17 19:54:12,110 nuclio (D) writing data to Stream {"record": {"text": "RT @BasedBasterd: As @Google's own CEO says that the Russians spent a measly $4,700.00 on the 2016 election.....you people have lost your m\u2026", "user": "@fightin2Bfree", "id": 1074754631161573382, "created_at": "Mon Dec 17 19:54:06 +0000 2018", "polarity": -0.022222222222222254, "subjectivity": 0.6555555555555556}}
# 2018-12-17 19:54:30,021 nuclio (D) writing data to Stream {"record": {"text": "@RepMattGaetz @Google Hey Matt, I\u2019m getting a feeling you\u2019re playing the old game of harassing companies until they\u2026 https://t.co/1TUkZvfc0e", "user": "@kj_mjr", "id": 1074754707086807041, "created_at": "Mon Dec 17 19:54:24 +0000 2018", "polarity": -0.15000000000000002, "subjectivity": 0.30000000000000004}}
# 2018-12-17 19:54:30,037 nuclio (D) writing data to Stream {"record": {"text": "@RepMattGaetz @Google Hey Matt, I\u2019m getting a feeling you\u2019re playing the old game of harassing companies until they\u2026 https://t.co/1TUkZvfc0e", "user": "@kj_mjr", "id": 1074754707086807041, "created_at": "Mon Dec 17 19:54:24 +0000 2018", "polarity": -0.15000000000000002, "subjectivity": 0.30000000000000004}}
# 2018-12-17 19:54:31,469 nuclio (D) writing data to Stream {"record": {"text": "RT @Viacom: #ViacomYearInReview: @amandaseales delivered straight \ud83d\udd25 at the inaugural #BETSocialAwards with her #BlackGirlMagic poem, causin\u2026", "user": "@trpmbadba", "id": 1074754712837197825, "created_at": "Mon Dec 17 19:54:26 +0000 2018", "polarity": 0.2, "subjectivity": 0.4}}
# 2018-12-17 19:54:31,482 nuclio (D) writing data to Stream {"record": {"text": "RT @Viacom: #ViacomYearInReview: @amandaseales delivered straight \ud83d\udd25 at the inaugural #BETSocialAwards with her #BlackGirlMagic poem, causin\u2026", "user": "@trpmbadba", "id": 1074754712837197825, "created_at": "Mon Dec 17 19:54:26 +0000 2018", "polarity": 0.2, "subjectivity": 0.4}}
# 2018-12-17 19:54:32,553 nuclio (D) writing data to Stream {"record": {"text": "Thanks to @Google @facebook @VisaNews @geidco @IKEAtoday @UITPnews @uic @iberdrola @usina_itaipu @itaipuparaguay fo\u2026 https://t.co/LHjmHquveQ", "user": "@OvaisSarmad", "id": 1074754717123833856, "created_at": "Mon Dec 17 19:54:27 +0000 2018", "polarity": 0.2, "subjectivity": 0.2}}
# 2018-12-17 19:54:32,556 nuclio (D) writing data to Stream {"record": {"text": "Thanks to @Google @facebook @VisaNews @geidco @IKEAtoday @UITPnews @uic @iberdrola @usina_itaipu @itaipuparaguay fo\u2026 https://t.co/LHjmHquveQ", "user": "@OvaisSarmad", "id": 1074754717123833856, "created_at": "Mon Dec 17 19:54:27 +0000 2018", "polarity": 0.2, "subjectivity": 0.2}}
# 2018-12-17 19:54:44,628 nuclio (D) writing data to Stream {"record": {"text": "RT @matchmadetv: Awesome wins, @PUBGMobile! Congrats on being crowned as 2018's Best Game AND \"Fan Favorite\" Game on @GooglePlay: https://t\u2026", "user": "@kellychiuuuu", "id": 1074754768185319424, "created_at": "Mon Dec 17 19:54:39 +0000 2018", "polarity": 0.3333333333333333, "subjectivity": 0.5499999999999999}}
# 2018-12-17 19:54:44,638 nuclio (D) writing data to Stream {"record": {"text": "RT @matchmadetv: Awesome wins, @PUBGMobile! Congrats on being crowned as 2018's Best Game AND \"Fan Favorite\" Game on @GooglePlay: https://t\u2026", "user": "@kellychiuuuu", "id": 1074754768185319424, "created_at": "Mon Dec 17 19:54:39 +0000 2018", "polarity": 0.3333333333333333, "subjectivity": 0.5499999999999999}}
# 2018-12-17 19:54:47,725 nuclio (D) writing data to Stream {"record": {"text": "RT @RepMattGaetz: ...but I would have been more encouraged if @Google would have acknowledged there is bias &amp; that they are taking actions\u2026", "user": "@EckleyToni", "id": 1074754781380517888, "created_at": "Mon Dec 17 19:54:42 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 19:54:47,730 nuclio (D) writing data to Stream {"record": {"text": "RT @RepMattGaetz: ...but I would have been more encouraged if @Google would have acknowledged there is bias &amp; that they are taking actions\u2026", "user": "@EckleyToni", "id": 1074754781380517888, "created_at": "Mon Dec 17 19:54:42 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 19:55:11,090 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@LVDGAVA", "id": 1074754878961016832, "created_at": "Mon Dec 17 19:55:05 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:55:11,120 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@LVDGAVA", "id": 1074754878961016832, "created_at": "Mon Dec 17 19:55:05 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:55:13,409 nuclio (D) writing data to Stream {"record": {"text": "Nine students from NASH toured @Google Pittsburgh last week through the World Affairs Council\u2019s Global Leadership C\u2026 https://t.co/0VrJkNbNto", "user": "@NA_Schools", "id": 1074754884971491328, "created_at": "Mon Dec 17 19:55:07 +0000 2018", "polarity": 0.0, "subjectivity": 0.03333333333333333}}
# 2018-12-17 19:55:13,422 nuclio (D) writing data to Stream {"record": {"text": "Nine students from NASH toured @Google Pittsburgh last week through the World Affairs Council\u2019s Global Leadership C\u2026 https://t.co/0VrJkNbNto", "user": "@NA_Schools", "id": 1074754884971491328, "created_at": "Mon Dec 17 19:55:07 +0000 2018", "polarity": 0.0, "subjectivity": 0.03333333333333333}}
# 2018-12-17 19:55:35,028 nuclio (D) writing data to Stream {"record": {"text": "RT @NBAAllStar: #NBAAllStar Voting 2019 presented by @Google, which is now the league\u2019s presenting #NBAAllStar Voting partner, will begin D\u2026", "user": "@hyattwastings", "id": 1074754979603243008, "created_at": "Mon Dec 17 19:55:29 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:55:35,049 nuclio (D) writing data to Stream {"record": {"text": "RT @NBAAllStar: #NBAAllStar Voting 2019 presented by @Google, which is now the league\u2019s presenting #NBAAllStar Voting partner, will begin D\u2026", "user": "@hyattwastings", "id": 1074754979603243008, "created_at": "Mon Dec 17 19:55:29 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:55:41,361 nuclio (D) writing data to Stream {"record": {"text": "RT @BasedBasterd: As @Google's own CEO says that the Russians spent a measly $4,700.00 on the 2016 election.....you people have lost your m\u2026", "user": "@rutesperanza", "id": 1074755005217996802, "created_at": "Mon Dec 17 19:55:35 +0000 2018", "polarity": -0.022222222222222254, "subjectivity": 0.6555555555555556}}
# 2018-12-17 19:55:41,366 nuclio (D) writing data to Stream {"record": {"text": "RT @BasedBasterd: As @Google's own CEO says that the Russians spent a measly $4,700.00 on the 2016 election.....you people have lost your m\u2026", "user": "@rutesperanza", "id": 1074755005217996802, "created_at": "Mon Dec 17 19:55:35 +0000 2018", "polarity": -0.022222222222222254, "subjectivity": 0.6555555555555556}}
# 2018-12-17 19:55:44,317 nuclio (D) writing data to Stream {"record": {"text": "RT @reginutedoll: Dear @Google , please revamp @GooglePlus . @Facebook and @Instagram are trash.....Toss a relevant (young) celebrity or tw\u2026", "user": "@ngan57468126", "id": 1074755017645715456, "created_at": "Mon Dec 17 19:55:38 +0000 2018", "polarity": 0.25, "subjectivity": 0.65}}
# 2018-12-17 19:55:44,320 nuclio (D) writing data to Stream {"record": {"text": "RT @reginutedoll: Dear @Google , please revamp @GooglePlus . @Facebook and @Instagram are trash.....Toss a relevant (young) celebrity or tw\u2026", "user": "@ngan57468126", "id": 1074755017645715456, "created_at": "Mon Dec 17 19:55:38 +0000 2018", "polarity": 0.25, "subjectivity": 0.65}}
# 2018-12-17 19:55:52,336 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@DeborahSebbors", "id": 1074755051443421189, "created_at": "Mon Dec 17 19:55:46 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:55:52,349 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@DeborahSebbors", "id": 1074755051443421189, "created_at": "Mon Dec 17 19:55:46 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:55:53,322 nuclio (D) writing data to Stream {"record": {"text": "RT @RepMattGaetz: ...but I would have been more encouraged if @Google would have acknowledged there is bias &amp; that they are taking actions\u2026", "user": "@ginkmeister13", "id": 1074755056497504256, "created_at": "Mon Dec 17 19:55:48 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 19:55:53,335 nuclio (D) writing data to Stream {"record": {"text": "RT @RepMattGaetz: ...but I would have been more encouraged if @Google would have acknowledged there is bias &amp; that they are taking actions\u2026", "user": "@ginkmeister13", "id": 1074755056497504256, "created_at": "Mon Dec 17 19:55:48 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 19:56:05,251 nuclio (D) writing data to Stream {"record": {"text": "\"I just don\u2019t think that\u2019s good enough,\" PM @jacindaardern says of @Google\u2019s lackadaisical approach to NZ name supp\u2026 https://t.co/7TUp7zc7oX", "user": "@1NewsNZ", "id": 1074755105897963522, "created_at": "Mon Dec 17 19:55:59 +0000 2018", "polarity": 0.35, "subjectivity": 0.55}}
# 2018-12-17 19:56:05,263 nuclio (D) writing data to Stream {"record": {"text": "\"I just don\u2019t think that\u2019s good enough,\" PM @jacindaardern says of @Google\u2019s lackadaisical approach to NZ name supp\u2026 https://t.co/7TUp7zc7oX", "user": "@1NewsNZ", "id": 1074755105897963522, "created_at": "Mon Dec 17 19:55:59 +0000 2018", "polarity": 0.35, "subjectivity": 0.55}}
# 2018-12-17 19:56:30,496 nuclio (D) writing data to Stream {"record": {"text": "@aMichelazzi @Google 90% of people would definitely pick the overexposed one \ud83d\udc4c", "user": "@Sgnoogle", "id": 1074755212546580481, "created_at": "Mon Dec 17 19:56:25 +0000 2018", "polarity": 0.0, "subjectivity": 0.5}}
# 2018-12-17 19:56:30,509 nuclio (D) writing data to Stream {"record": {"text": "@aMichelazzi @Google 90% of people would definitely pick the overexposed one \ud83d\udc4c", "user": "@Sgnoogle", "id": 1074755212546580481, "created_at": "Mon Dec 17 19:56:25 +0000 2018", "polarity": 0.0, "subjectivity": 0.5}}
# 2018-12-17 19:56:31,301 nuclio (D) writing data to Stream {"record": {"text": "What I'd really like to know is why does @Google keep trying to sell me business listings. I DON\"T OWN A BUSINESS Y\u2026 https://t.co/DwTPQ7BH3r", "user": "@doc4153", "id": 1074755215851630592, "created_at": "Mon Dec 17 19:56:26 +0000 2018", "polarity": 0.4, "subjectivity": 0.6}}
# 2018-12-17 19:56:31,311 nuclio (D) writing data to Stream {"record": {"text": "What I'd really like to know is why does @Google keep trying to sell me business listings. I DON\"T OWN A BUSINESS Y\u2026 https://t.co/DwTPQ7BH3r", "user": "@doc4153", "id": 1074755215851630592, "created_at": "Mon Dec 17 19:56:26 +0000 2018", "polarity": 0.4, "subjectivity": 0.6}}
# 2018-12-17 19:56:39,322 nuclio (D) writing data to Stream {"record": {"text": "RT @NBAAllStar: #NBAAllStar Voting 2019 presented by @Google, which is now the league\u2019s presenting #NBAAllStar Voting partner, will begin D\u2026", "user": "@pollolfito", "id": 1074755249200553984, "created_at": "Mon Dec 17 19:56:34 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:56:39,332 nuclio (D) writing data to Stream {"record": {"text": "RT @NBAAllStar: #NBAAllStar Voting 2019 presented by @Google, which is now the league\u2019s presenting #NBAAllStar Voting partner, will begin D\u2026", "user": "@pollolfito", "id": 1074755249200553984, "created_at": "Mon Dec 17 19:56:34 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:56:44,226 nuclio (D) writing data to Stream {"record": {"text": "RT @davidhratner: I rarely say this, but really impressed with @Google and the process to buy a new #pixel3XL.  Within 24 hours an actual p\u2026", "user": "@DaveKSecure", "id": 1074755270008496129, "created_at": "Mon Dec 17 19:56:39 +0000 2018", "polarity": 0.3590909090909091, "subjectivity": 0.6136363636363636}}
# 2018-12-17 19:56:44,228 nuclio (D) writing data to Stream {"record": {"text": "RT @davidhratner: I rarely say this, but really impressed with @Google and the process to buy a new #pixel3XL.  Within 24 hours an actual p\u2026", "user": "@DaveKSecure", "id": 1074755270008496129, "created_at": "Mon Dec 17 19:56:39 +0000 2018", "polarity": 0.3590909090909091, "subjectivity": 0.6136363636363636}}
# 2018-12-17 19:56:45,163 nuclio (D) writing data to Stream {"record": {"text": "RT @BasedBasterd: As @Google's own CEO says that the Russians spent a measly $4,700.00 on the 2016 election.....you people have lost your m\u2026", "user": "@SSJQ5", "id": 1074755273087021057, "created_at": "Mon Dec 17 19:56:39 +0000 2018", "polarity": -0.022222222222222254, "subjectivity": 0.6555555555555556}}
# 2018-12-17 19:56:45,185 nuclio (D) writing data to Stream {"record": {"text": "RT @BasedBasterd: As @Google's own CEO says that the Russians spent a measly $4,700.00 on the 2016 election.....you people have lost your m\u2026", "user": "@SSJQ5", "id": 1074755273087021057, "created_at": "Mon Dec 17 19:56:39 +0000 2018", "polarity": -0.022222222222222254, "subjectivity": 0.6555555555555556}}
# 2018-12-17 19:56:56,799 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@Supergeles", "id": 1074755322244423682, "created_at": "Mon Dec 17 19:56:51 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:56:56,814 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@Supergeles", "id": 1074755322244423682, "created_at": "Mon Dec 17 19:56:51 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:05,387 nuclio (D) writing data to Stream {"record": {"text": "RT @osde8info: ibm #aix #power9 @google #linuxinginlondon @skillsmatter #codenode https://t.co/GMXnZ98Vqq", "user": "@DavidScreative", "id": 1074755358466420736, "created_at": "Mon Dec 17 19:57:00 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:05,398 nuclio (D) writing data to Stream {"record": {"text": "RT @osde8info: ibm #aix #power9 @google #linuxinginlondon @skillsmatter #codenode https://t.co/GMXnZ98Vqq", "user": "@DavidScreative", "id": 1074755358466420736, "created_at": "Mon Dec 17 19:57:00 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:06,793 nuclio (D) writing data to Stream {"record": {"text": "@RepMattGaetz @Google They will lie all day long", "user": "@kinh_nguyen9", "id": 1074755364627845120, "created_at": "Mon Dec 17 19:57:01 +0000 2018", "polarity": -0.05, "subjectivity": 0.4}}
# 2018-12-17 19:57:06,804 nuclio (D) writing data to Stream {"record": {"text": "@RepMattGaetz @Google They will lie all day long", "user": "@kinh_nguyen9", "id": 1074755364627845120, "created_at": "Mon Dec 17 19:57:01 +0000 2018", "polarity": -0.05, "subjectivity": 0.4}}
# 2018-12-17 19:57:08,216 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@merinales", "id": 1074755370332098561, "created_at": "Mon Dec 17 19:57:02 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:08,228 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@merinales", "id": 1074755370332098561, "created_at": "Mon Dec 17 19:57:02 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:11,741 nuclio (D) writing data to Stream {"record": {"text": "#Ent\u00e9rate #Francia aplicar\u00e1 impuesto especial a @Google , @Apple, @facebook y @Amazon  https://t.co/pSbaDMUl6N https://t.co/tqRkGYVXiN", "user": "@Efekto10", "id": 1074755380499177473, "created_at": "Mon Dec 17 19:57:05 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:11,760 nuclio (D) writing data to Stream {"record": {"text": "#Ent\u00e9rate #Francia aplicar\u00e1 impuesto especial a @Google , @Apple, @facebook y @Amazon  https://t.co/pSbaDMUl6N https://t.co/tqRkGYVXiN", "user": "@Efekto10", "id": 1074755380499177473, "created_at": "Mon Dec 17 19:57:05 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:13,331 nuclio (D) writing data to Stream {"record": {"text": "@BsiLiAdeL @ARPtn @AlBawsalaTN @Google \u063a\u062f\u0648\u0629 \u0639\u0627 \u0627\u0644\u0635\u0628\u0627\u062d", "user": "@MyriamBoujbel", "id": 1074755392297725953, "created_at": "Mon Dec 17 19:57:08 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:13,339 nuclio (D) writing data to Stream {"record": {"text": "@BsiLiAdeL @ARPtn @AlBawsalaTN @Google \u063a\u062f\u0648\u0629 \u0639\u0627 \u0627\u0644\u0635\u0628\u0627\u062d", "user": "@MyriamBoujbel", "id": 1074755392297725953, "created_at": "Mon Dec 17 19:57:08 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:22,824 nuclio (D) writing data to Stream {"record": {"text": "@Google SweAs\u3068ww", "user": "@justt_lauren", "id": 1074755432038756355, "created_at": "Mon Dec 17 19:57:17 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:22,835 nuclio (D) writing data to Stream {"record": {"text": "@Google SweAs\u3068ww", "user": "@justt_lauren", "id": 1074755432038756355, "created_at": "Mon Dec 17 19:57:17 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:24,658 nuclio (D) writing data to Stream {"record": {"text": "@Google | I will always Love you \ud83c\udf81\u2764\ufe0f https://t.co/CV2RxuYEE6", "user": "@saedalsaleh1", "id": 1074755438120456197, "created_at": "Mon Dec 17 19:57:19 +0000 2018", "polarity": 0.5, "subjectivity": 0.6}}
# 2018-12-17 19:57:24,673 nuclio (D) writing data to Stream {"record": {"text": "@Google | I will always Love you \ud83c\udf81\u2764\ufe0f https://t.co/CV2RxuYEE6", "user": "@saedalsaleh1", "id": 1074755438120456197, "created_at": "Mon Dec 17 19:57:19 +0000 2018", "polarity": 0.5, "subjectivity": 0.6}}
# 2018-12-17 19:57:36,159 nuclio (D) writing data to Stream {"record": {"text": "RT @NBAAllStar: #NBAAllStar Voting 2019 presented by @Google, which is now the league\u2019s presenting #NBAAllStar Voting partner, will begin D\u2026", "user": "@loncletoma", "id": 1074755487684534272, "created_at": "Mon Dec 17 19:57:30 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:36,172 nuclio (D) writing data to Stream {"record": {"text": "RT @NBAAllStar: #NBAAllStar Voting 2019 presented by @Google, which is now the league\u2019s presenting #NBAAllStar Voting partner, will begin D\u2026", "user": "@loncletoma", "id": 1074755487684534272, "created_at": "Mon Dec 17 19:57:30 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:42,274 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@khvdidjaa", "id": 1074755513588559874, "created_at": "Mon Dec 17 19:57:37 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:42,296 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@khvdidjaa", "id": 1074755513588559874, "created_at": "Mon Dec 17 19:57:37 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:48,803 nuclio (D) writing data to Stream {"record": {"text": "RT @MedTechStrat: Given the stigma of wearing #hearingaids and their association with aging, does this level of #technology (@Apple, @Googl\u2026", "user": "@dunn_steffanie", "id": 1074755540675321856, "created_at": "Mon Dec 17 19:57:43 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:48,809 nuclio (D) writing data to Stream {"record": {"text": "RT @MedTechStrat: Given the stigma of wearing #hearingaids and their association with aging, does this level of #technology (@Apple, @Googl\u2026", "user": "@dunn_steffanie", "id": 1074755540675321856, "created_at": "Mon Dec 17 19:57:43 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:58,260 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@flyingpotato099", "id": 1074755580525465600, "created_at": "Mon Dec 17 19:57:53 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:57:58,277 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@flyingpotato099", "id": 1074755580525465600, "created_at": "Mon Dec 17 19:57:53 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:58:24,139 nuclio (D) writing data to Stream {"record": {"text": "RT @GoogleDesign: \ud83e\udd41Our #BestOf2018 just dropped! From everyday excellence in ML to crafting accessible UX, join us as we highlight the best\u2026", "user": "@alanjone_", "id": 1074755688876961793, "created_at": "Mon Dec 17 19:58:18 +0000 2018", "polarity": 0.39166666666666666, "subjectivity": 0.425}}
# 2018-12-17 19:58:24,158 nuclio (D) writing data to Stream {"record": {"text": "RT @GoogleDesign: \ud83e\udd41Our #BestOf2018 just dropped! From everyday excellence in ML to crafting accessible UX, join us as we highlight the best\u2026", "user": "@alanjone_", "id": 1074755688876961793, "created_at": "Mon Dec 17 19:58:18 +0000 2018", "polarity": 0.39166666666666666, "subjectivity": 0.425}}
# 2018-12-17 19:58:28,850 nuclio (D) writing data to Stream {"record": {"text": "RT @monsterhunter: Gather \u2018round, hunters - #MHWorld was one of @Google\u2019s top trending video games of 2018. #YearInSearch https://t.co/4zfc\u2026", "user": "@FutureMcGuives", "id": 1074755708846030849, "created_at": "Mon Dec 17 19:58:23 +0000 2018", "polarity": 0.15, "subjectivity": 0.45}}
# 2018-12-17 19:58:28,863 nuclio (D) writing data to Stream {"record": {"text": "RT @monsterhunter: Gather \u2018round, hunters - #MHWorld was one of @Google\u2019s top trending video games of 2018. #YearInSearch https://t.co/4zfc\u2026", "user": "@FutureMcGuives", "id": 1074755708846030849, "created_at": "Mon Dec 17 19:58:23 +0000 2018", "polarity": 0.15, "subjectivity": 0.45}}
# 2018-12-17 19:58:34,711 nuclio (D) writing data to Stream {"record": {"text": "@GOOGLE https://t.co/fWR8Hit7Nd YES.  GOOGLE TRACKS YOUR LOCATION AND WHERE YOU GO. #GOOGLE (GO OGLE) OGLE: stare a\u2026 https://t.co/mKrc5YmtbK", "user": "@ptonfm", "id": 1074755733307179008, "created_at": "Mon Dec 17 19:58:29 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:58:34,722 nuclio (D) writing data to Stream {"record": {"text": "@GOOGLE https://t.co/fWR8Hit7Nd YES.  GOOGLE TRACKS YOUR LOCATION AND WHERE YOU GO. #GOOGLE (GO OGLE) OGLE: stare a\u2026 https://t.co/mKrc5YmtbK", "user": "@ptonfm", "id": 1074755733307179008, "created_at": "Mon Dec 17 19:58:29 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:58:38,549 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@SebasFC", "id": 1074755749304299521, "created_at": "Mon Dec 17 19:58:33 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:58:38,569 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@SebasFC", "id": 1074755749304299521, "created_at": "Mon Dec 17 19:58:33 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:58:43,769 nuclio (D) writing data to Stream {"record": {"text": "@kaufer", "user": "@helixx85", "id": 1074755769877364736, "created_at": "Mon Dec 17 19:58:38 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:58:43,782 nuclio (D) writing data to Stream {"record": {"text": "@kaufer", "user": "@helixx85", "id": 1074755769877364736, "created_at": "Mon Dec 17 19:58:38 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:58:58,407 nuclio (D) writing data to Stream {"record": {"text": "Help a guy out with a retweet? @pcworld @PCMag @macworld @WIRED @MaximumPC @pcgamer @Computerworld @pcpro https://t.co/aq99jv1l8H", "user": "@afotikzone", "id": 1074755832376713217, "created_at": "Mon Dec 17 19:58:53 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:58:58,410 nuclio (D) writing data to Stream {"record": {"text": "Help a guy out with a retweet? @pcworld @PCMag @macworld @WIRED @MaximumPC @pcgamer @Computerworld @pcpro https://t.co/aq99jv1l8H", "user": "@afotikzone", "id": 1074755832376713217, "created_at": "Mon Dec 17 19:58:53 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:59:02,176 nuclio (D) writing data to Stream {"record": {"text": "Once you actually figure out how to get in touch with @Google support, they are quite nice and helpful.", "user": "@BenDiPiero", "id": 1074755848658976773, "created_at": "Mon Dec 17 19:58:56 +0000 2018", "polarity": 0.3, "subjectivity": 0.55}}
# 2018-12-17 19:59:02,182 nuclio (D) writing data to Stream {"record": {"text": "Once you actually figure out how to get in touch with @Google support, they are quite nice and helpful.", "user": "@BenDiPiero", "id": 1074755848658976773, "created_at": "Mon Dec 17 19:58:56 +0000 2018", "polarity": 0.3, "subjectivity": 0.55}}
# 2018-12-17 19:59:08,293 nuclio (D) writing data to Stream {"record": {"text": "RT @QueenWillRock: Thank YOU for making #BohemianRhapsody the top trending song of 2018\n\n@Google #yearinsearch https://t.co/1bsVPaOYYq", "user": "@martindelia_", "id": 1074755874135117824, "created_at": "Mon Dec 17 19:59:03 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 19:59:08,307 nuclio (D) writing data to Stream {"record": {"text": "RT @QueenWillRock: Thank YOU for making #BohemianRhapsody the top trending song of 2018\n\n@Google #yearinsearch https://t.co/1bsVPaOYYq", "user": "@martindelia_", "id": 1074755874135117824, "created_at": "Mon Dec 17 19:59:03 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 19:59:13,089 nuclio (D) writing data to Stream {"record": {"text": "@edventures @shirky17 @Google Seeing this as well. What have you heard from support?", "user": "@IT_guy8706", "id": 1074755894511104001, "created_at": "Mon Dec 17 19:59:07 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:59:13,102 nuclio (D) writing data to Stream {"record": {"text": "@edventures @shirky17 @Google Seeing this as well. What have you heard from support?", "user": "@IT_guy8706", "id": 1074755894511104001, "created_at": "Mon Dec 17 19:59:07 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:59:36,500 nuclio (D) writing data to Stream {"record": {"text": "Die Wahrheit hinter der Wahrheit und seinen Web.-Portalen (Netzwerken): Unter dem Strich gesagt, liegt es an jedem\u2026 https://t.co/Tvsc3QEPpo", "user": "@awstefan2012", "id": 1074755992037060608, "created_at": "Mon Dec 17 19:59:31 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:59:36,503 nuclio (D) writing data to Stream {"record": {"text": "Die Wahrheit hinter der Wahrheit und seinen Web.-Portalen (Netzwerken): Unter dem Strich gesagt, liegt es an jedem\u2026 https://t.co/Tvsc3QEPpo", "user": "@awstefan2012", "id": 1074755992037060608, "created_at": "Mon Dec 17 19:59:31 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 19:59:51,959 nuclio (D) writing data to Stream {"record": {"text": "@digitalbayinc @Google @gmail @googlefi @_MintMobile Thanks for your support!", "user": "@ProtonMail", "id": 1074756057547841537, "created_at": "Mon Dec 17 19:59:46 +0000 2018", "polarity": 0.2, "subjectivity": 0.2}}
# 2018-12-17 19:59:51,962 nuclio (D) writing data to Stream {"record": {"text": "@digitalbayinc @Google @gmail @googlefi @_MintMobile Thanks for your support!", "user": "@ProtonMail", "id": 1074756057547841537, "created_at": "Mon Dec 17 19:59:46 +0000 2018", "polarity": 0.2, "subjectivity": 0.2}}
# 2018-12-17 20:00:02,340 nuclio (D) writing data to Stream {"record": {"text": "RT @CFiPilotMEi: @hope4America2dy @Patrick53971412 @ElizabethBotros @kidvamp8724 @GoodVibes58 @BorthwickKathy @flamethrower82 @PatrickMcGil\u2026", "user": "@flamethrower82", "id": 1074756100057120770, "created_at": "Mon Dec 17 19:59:56 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:02,398 nuclio (D) writing data to Stream {"record": {"text": "RT @CFiPilotMEi: @hope4America2dy @Patrick53971412 @ElizabethBotros @kidvamp8724 @GoodVibes58 @BorthwickKathy @flamethrower82 @PatrickMcGil\u2026", "user": "@flamethrower82", "id": 1074756100057120770, "created_at": "Mon Dec 17 19:59:56 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:08,132 nuclio (D) writing data to Stream {"record": {"text": "RT @Efekto10: #Ent\u00e9rate #Francia aplicar\u00e1 impuesto especial a @Google , @Apple, @facebook y @Amazon  https://t.co/pSbaDMUl6N https://t.co/t\u2026", "user": "@mipropialey", "id": 1074756124488941568, "created_at": "Mon Dec 17 20:00:02 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:08,145 nuclio (D) writing data to Stream {"record": {"text": "RT @Efekto10: #Ent\u00e9rate #Francia aplicar\u00e1 impuesto especial a @Google , @Apple, @facebook y @Amazon  https://t.co/pSbaDMUl6N https://t.co/t\u2026", "user": "@mipropialey", "id": 1074756124488941568, "created_at": "Mon Dec 17 20:00:02 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:14,395 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@irismlkk", "id": 1074756151521226752, "created_at": "Mon Dec 17 20:00:09 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:14,421 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@irismlkk", "id": 1074756151521226752, "created_at": "Mon Dec 17 20:00:09 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:15,203 nuclio (D) writing data to Stream {"record": {"text": "RT @CFiPilotMEi: @hope4America2dy @Patrick53971412 @ElizabethBotros @kidvamp8724 @GoodVibes58 @BorthwickKathy @flamethrower82 @PatrickMcGil\u2026", "user": "@flamethrower82", "id": 1074756153731661825, "created_at": "Mon Dec 17 20:00:09 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:15,223 nuclio (D) writing data to Stream {"record": {"text": "RT @CFiPilotMEi: @hope4America2dy @Patrick53971412 @ElizabethBotros @kidvamp8724 @GoodVibes58 @BorthwickKathy @flamethrower82 @PatrickMcGil\u2026", "user": "@flamethrower82", "id": 1074756153731661825, "created_at": "Mon Dec 17 20:00:09 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:19,527 nuclio (D) writing data to Stream {"record": {"text": "RT @CFiPilotMEi: @hope4America2dy @Patrick53971412 @ElizabethBotros @kidvamp8724 @GoodVibes58 @BorthwickKathy @flamethrower82 @PatrickMcGil\u2026", "user": "@flamethrower82", "id": 1074756172194959361, "created_at": "Mon Dec 17 20:00:14 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:19,560 nuclio (D) writing data to Stream {"record": {"text": "RT @CFiPilotMEi: @hope4America2dy @Patrick53971412 @ElizabethBotros @kidvamp8724 @GoodVibes58 @BorthwickKathy @flamethrower82 @PatrickMcGil\u2026", "user": "@flamethrower82", "id": 1074756172194959361, "created_at": "Mon Dec 17 20:00:14 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:32,171 nuclio (D) writing data to Stream {"record": {"text": "Did you know you can encourage @Google to crawl a page a bit faster by testing the live URL and then requesting ind\u2026 https://t.co/wiAiWEz4bZ", "user": "@DeepCrawl", "id": 1074756225517191169, "created_at": "Mon Dec 17 20:00:26 +0000 2018", "polarity": 0.13636363636363635, "subjectivity": 0.5}}
# 2018-12-17 20:00:32,173 nuclio (D) writing data to Stream {"record": {"text": "Did you know you can encourage @Google to crawl a page a bit faster by testing the live URL and then requesting ind\u2026 https://t.co/wiAiWEz4bZ", "user": "@DeepCrawl", "id": 1074756225517191169, "created_at": "Mon Dec 17 20:00:26 +0000 2018", "polarity": 0.13636363636363635, "subjectivity": 0.5}}
# 2018-12-17 20:00:34,096 nuclio (D) writing data to Stream {"record": {"text": "RT @hope4America2dy: @CFiPilotMEi @Patrick53971412 @ElizabethBotros @kidvamp8724 @GoodVibes58 @BorthwickKathy @flamethrower82 @PatrickMcGil\u2026", "user": "@flamethrower82", "id": 1074756233121402880, "created_at": "Mon Dec 17 20:00:28 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:34,114 nuclio (D) writing data to Stream {"record": {"text": "RT @hope4America2dy: @CFiPilotMEi @Patrick53971412 @ElizabethBotros @kidvamp8724 @GoodVibes58 @BorthwickKathy @flamethrower82 @PatrickMcGil\u2026", "user": "@flamethrower82", "id": 1074756233121402880, "created_at": "Mon Dec 17 20:00:28 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:00:34,992 nuclio (D) writing data to Stream {"record": {"text": "RT @davidfarrier: hey @YouTube (and ur parents @Google) - your system is broken. in your quest to monetise you\u2019re verifying fetish videos w\u2026", "user": "@atomicboop", "id": 1074756237533696001, "created_at": "Mon Dec 17 20:00:29 +0000 2018", "polarity": -0.4, "subjectivity": 0.4}}
# 2018-12-17 20:00:34,995 nuclio (D) writing data to Stream {"record": {"text": "RT @davidfarrier: hey @YouTube (and ur parents @Google) - your system is broken. in your quest to monetise you\u2019re verifying fetish videos w\u2026", "user": "@atomicboop", "id": 1074756237533696001, "created_at": "Mon Dec 17 20:00:29 +0000 2018", "polarity": -0.4, "subjectivity": 0.4}}
# 2018-12-17 20:00:48,222 nuclio (D) writing data to Stream {"record": {"text": "RT @RepMattGaetz: ...but I would have been more encouraged if @Google would have acknowledged there is bias &amp; that they are taking actions\u2026", "user": "@medpass37", "id": 1074756293339086848, "created_at": "Mon Dec 17 20:00:42 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 20:00:48,238 nuclio (D) writing data to Stream {"record": {"text": "RT @RepMattGaetz: ...but I would have been more encouraged if @Google would have acknowledged there is bias &amp; that they are taking actions\u2026", "user": "@medpass37", "id": 1074756293339086848, "created_at": "Mon Dec 17 20:00:42 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 20:01:05,670 nuclio (D) writing data to Stream {"record": {"text": "RT @galeabrewer: It\u2019s great that NY continues to grow as a tech hub and that @Google is expanding here. Now we need to work with @CUNY and\u2026", "user": "@dangeiger79", "id": 1074756366252863488, "created_at": "Mon Dec 17 20:01:00 +0000 2018", "polarity": 0.8, "subjectivity": 0.75}}
# 2018-12-17 20:01:05,673 nuclio (D) writing data to Stream {"record": {"text": "RT @galeabrewer: It\u2019s great that NY continues to grow as a tech hub and that @Google is expanding here. Now we need to work with @CUNY and\u2026", "user": "@dangeiger79", "id": 1074756366252863488, "created_at": "Mon Dec 17 20:01:00 +0000 2018", "polarity": 0.8, "subjectivity": 0.75}}
# 2018-12-17 20:01:07,447 nuclio (D) writing data to Stream {"record": {"text": "RT @NBAAllStar: #NBAAllStar Voting 2019 presented by @Google, which is now the league\u2019s presenting #NBAAllStar Voting partner, will begin D\u2026", "user": "@Run171", "id": 1074756373798445063, "created_at": "Mon Dec 17 20:01:02 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:01:07,473 nuclio (D) writing data to Stream {"record": {"text": "RT @NBAAllStar: #NBAAllStar Voting 2019 presented by @Google, which is now the league\u2019s presenting #NBAAllStar Voting partner, will begin D\u2026", "user": "@Run171", "id": 1074756373798445063, "created_at": "Mon Dec 17 20:01:02 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:01:11,895 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@Karmaleonic", "id": 1074756392370753538, "created_at": "Mon Dec 17 20:01:06 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:01:11,897 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@Karmaleonic", "id": 1074756392370753538, "created_at": "Mon Dec 17 20:01:06 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:01:14,210 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@borde_g", "id": 1074756402491650054, "created_at": "Mon Dec 17 20:01:09 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:01:14,236 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@borde_g", "id": 1074756402491650054, "created_at": "Mon Dec 17 20:01:09 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:01:16,122 nuclio (D) writing data to Stream {"record": {"text": "@TheSlyStallone se despide de sus dos personajes m\u00e1s memorables: #Rocky y #Rambo, adem\u00e1s termina el a\u00f1o siendo el a\u2026 https://t.co/1e89uSPJ6M", "user": "@monterrey_360", "id": 1074756410368552960, "created_at": "Mon Dec 17 20:01:10 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:01:16,134 nuclio (D) writing data to Stream {"record": {"text": "@TheSlyStallone se despide de sus dos personajes m\u00e1s memorables: #Rocky y #Rambo, adem\u00e1s termina el a\u00f1o siendo el a\u2026 https://t.co/1e89uSPJ6M", "user": "@monterrey_360", "id": 1074756410368552960, "created_at": "Mon Dec 17 20:01:10 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:01:16,688 nuclio (D) writing data to Stream {"record": {"text": "RT @techsavvymama: Help kids create healthy digital habits with free tools like @Google #FamilyLink that covers safety &amp; privacy, screen ti\u2026", "user": "@Clarissa_xplain", "id": 1074756412700585984, "created_at": "Mon Dec 17 20:01:11 +0000 2018", "polarity": 0.3, "subjectivity": 0.43333333333333335}}
# 2018-12-17 20:01:16,692 nuclio (D) writing data to Stream {"record": {"text": "RT @techsavvymama: Help kids create healthy digital habits with free tools like @Google #FamilyLink that covers safety &amp; privacy, screen ti\u2026", "user": "@Clarissa_xplain", "id": 1074756412700585984, "created_at": "Mon Dec 17 20:01:11 +0000 2018", "polarity": 0.3, "subjectivity": 0.43333333333333335}}
# 2018-12-17 20:01:16,785 nuclio (D) writing data to Stream {"record": {"text": "@Google has been using WaveNet #AI technology to make the Google Assistant's spoken voice sound more human and less\u2026 https://t.co/URS7YZ4TWI", "user": "@mavenwave", "id": 1074756413010952192, "created_at": "Mon Dec 17 20:01:11 +0000 2018", "polarity": 0.18333333333333335, "subjectivity": 0.26666666666666666}}
# 2018-12-17 20:01:16,802 nuclio (D) writing data to Stream {"record": {"text": "@Google has been using WaveNet #AI technology to make the Google Assistant's spoken voice sound more human and less\u2026 https://t.co/URS7YZ4TWI", "user": "@mavenwave", "id": 1074756413010952192, "created_at": "Mon Dec 17 20:01:11 +0000 2018", "polarity": 0.18333333333333335, "subjectivity": 0.26666666666666666}}
# 2018-12-17 20:01:18,647 nuclio (D) writing data to Stream {"record": {"text": "#ICYMI:@Google just announced that their newest campus will be in #HudsonSquare. Our CEO, Ellen Baer spoke to the\u2026 https://t.co/GdPhVFBaot", "user": "@HudsonSquareNYC", "id": 1074756420812369925, "created_at": "Mon Dec 17 20:01:13 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:01:18,660 nuclio (D) writing data to Stream {"record": {"text": "#ICYMI:@Google just announced that their newest campus will be in #HudsonSquare. Our CEO, Ellen Baer spoke to the\u2026 https://t.co/GdPhVFBaot", "user": "@HudsonSquareNYC", "id": 1074756420812369925, "created_at": "Mon Dec 17 20:01:13 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# ...
#     self._original_response.close()
#   File "/conda/lib/python3.6/contextlib.py", line 99, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/conda/lib/python3.6/site-packages/urllib3/response.py", line 378, in _error_catcher
#     raise ProtocolError('Connection broken: %r' % e, e)
# urllib3.exceptions.ProtocolError: ('Connection broken: OSError("(104, \'ECONNRESET\')",)', OSError("(104, 'ECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/conda/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/conda/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-7-7f3dcbaf121c>", line 5, in start_listener
#     stream.start(process_event, 200, track='@Google', lang='en')
#   File "<ipython-input-6-10c6dfcea514>", line 32, in start
#     self.statuses.filter(**kw)
#   File "/conda/lib/python3.6/site-packages/twython/streaming/types.py", line 67, in filter
#     self.streamer._request(url, 'POST', params=params)
#   File "/conda/lib/python3.6/site-packages/twython/streaming/api.py", line 141, in _request
#     for line in response.iter_lines(self.chunk_size):
#   File "/conda/lib/python3.6/site-packages/requests/models.py", line 794, in iter_lines
#     for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#   File "/conda/lib/python3.6/site-packages/requests/models.py", line 753, in generate
#     raise ChunkedEncodingError(e)
# requests.exceptions.ChunkedEncodingError: ('Connection broken: OSError("(104, \'ECONNRESET\')",)', OSError("(104, 'ECONNRESET')",))
# 2018-12-17 20:14:33,858 nuclio (D) writing data to Stream {"record": {"text": "@google how can services be just killed like this? Orkut with updates would of have survived. As well as Picasa. No\u2026 https://t.co/JOqbHBzpYO", "user": "@ufopeace", "id": 1074759755636400128, "created_at": "Mon Dec 17 20:14:28 +0000 2018", "polarity": -0.2, "subjectivity": 0.0}}
# 2018-12-17 20:14:39,318 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@Maternitat_SEDR", "id": 1074759779044724738, "created_at": "Mon Dec 17 20:14:34 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:14:41,487 nuclio (D) writing data to Stream {"record": {"text": "@1NewsNZ @jacindaardern @Google @jacktame @Breakfaston1 A great week of deflection whilst winnie signs the UN Migration pact!\n#TreasonousPM", "user": "@ClawDove", "id": 1074759788272148482, "created_at": "Mon Dec 17 20:14:36 +0000 2018", "polarity": 0.8, "subjectivity": 0.75}}
# 2018-12-17 20:15:04,616 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@leo_matuidi", "id": 1074759885525532674, "created_at": "Mon Dec 17 20:14:59 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:15:07,602 nuclio (D) writing data to Stream {"record": {"text": "#squash \u2013 the answer you cannot get from @google - @englandsr", "user": "@SquashShrews", "id": 1074759897072525318, "created_at": "Mon Dec 17 20:15:02 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:15:09,128 nuclio (D) writing data to Stream {"record": {"text": "RT @joshrogin: It seems that even @google is susceptible to public pressure and shame. But they can never erase this stain on their reputat\u2026", "user": "@benjasonroberts", "id": 1074759903925932032, "created_at": "Mon Dec 17 20:15:03 +0000 2018", "polarity": 0.0, "subjectivity": 0.06666666666666667}}
# 2018-12-17 20:15:11,240 nuclio (D) writing data to Stream {"record": {"text": "RT @franckmen: Les 4 sites les plus visit\u00e9s en #France en 2018 : \n\ud83d\udc53@Google \n\ud83d\udcac@Facebook \n\ud83c\udfa5@Youtube \n\ud83d\udcda @wikipedia\n\ud83d\uded2@Leboncoin \nVous savez o\u00f9\u2026", "user": "@julienramauge", "id": 1074759913077755904, "created_at": "Mon Dec 17 20:15:06 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:15:13,386 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@SuperMami22", "id": 1074759922049531905, "created_at": "Mon Dec 17 20:15:08 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:15:16,520 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@tess_byrpl", "id": 1074759935282561029, "created_at": "Mon Dec 17 20:15:11 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:15:32,688 nuclio (D) writing data to Stream {"record": {"text": "No Surprise #EndTheWitchHuntNow !!! @cnn @msnbc @maddow @CNNPolitics @ABC @CBSNews @NBCNews @CBSTweet @CBS @nbc\u2026 https://t.co/rLBklGtcSv", "user": "@SherryWall20", "id": 1074760002563383298, "created_at": "Mon Dec 17 20:15:27 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:15:39,172 nuclio (D) writing data to Stream {"record": {"text": "@SpeerColleenSAP Posted... \nhttps://t.co/Npxt21i1Uz", "user": "@GratefulSaint", "id": 1074760029935452164, "created_at": "Mon Dec 17 20:15:33 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:15:54,258 nuclio (D) writing data to Stream {"record": {"text": "RT @CO_CDHS: Looking for the best place for #childcare in your part of #Colorado? We can help! Just like @Yelp or @Google reviews, @COShine\u2026", "user": "@coloradogov", "id": 1074760093412016138, "created_at": "Mon Dec 17 20:15:49 +0000 2018", "polarity": 1.0, "subjectivity": 0.3}}
# 2018-12-17 20:16:15,706 nuclio (D) writing data to Stream {"record": {"text": "#Francia impondr\u00e1 impuesto especial a @Google, @Apple, @facebook y @amazon \nhttps://t.co/0rlfimyJHG", "user": "@NoticiasMVS", "id": 1074760183384076288, "created_at": "Mon Dec 17 20:16:10 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:16:23,000 nuclio (D) writing data to Stream {"record": {"text": "RT @BasedBasterd: As @Google's own CEO says that the Russians spent a measly $4,700.00 on the 2016 election.....you people have lost your m\u2026", "user": "@jenn_mallory", "id": 1074760213641814017, "created_at": "Mon Dec 17 20:16:17 +0000 2018", "polarity": -0.022222222222222254, "subjectivity": 0.6555555555555556}}
# 2018-12-17 20:16:42,624 nuclio (D) writing data to Stream {"record": {"text": "RT @Stevo4747: We have entered the third age of #gaming. Is it the best? @Amazon @Microsoft @Google @TencentGlobal think so. @MorrisatLarge\u2026", "user": "@EdGameTec", "id": 1074760296152080389, "created_at": "Mon Dec 17 20:16:37 +0000 2018", "polarity": 0.5, "subjectivity": 0.15}}
# 2018-12-17 20:16:44,506 nuclio (D) writing data to Stream {"record": {"text": "RT @NBAAllStar: #NBAAllStar Voting 2019 presented by @Google, which is now the league\u2019s presenting #NBAAllStar Voting partner, will begin D\u2026", "user": "@dmyles728", "id": 1074760302498058246, "created_at": "Mon Dec 17 20:16:38 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:17:02,086 nuclio (D) writing data to Stream {"record": {"text": "@SpencerAlthouse Thank you @Google", "user": "@esemejeomole", "id": 1074760378054250502, "created_at": "Mon Dec 17 20:16:56 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:17:03,886 nuclio (D) writing data to Stream {"record": {"text": "RT @RepMattGaetz: ...but I would have been more encouraged if @Google would have acknowledged there is bias &amp; that they are taking actions\u2026", "user": "@ToniS7575", "id": 1074760385461448705, "created_at": "Mon Dec 17 20:16:58 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 20:17:12,128 nuclio (D) writing data to Stream {"record": {"text": "Yes #EndTheWitchHuntNow !!! @cnn @msnbc @maddow @CNNPolitics @ABCPolitics @ABC @CBSNews @NBCNews @CBSTweet @CBS\u2026 https://t.co/X5xnVU40sl", "user": "@SherryWall20", "id": 1074760419825332224, "created_at": "Mon Dec 17 20:17:06 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:17:14,389 nuclio (D) writing data to Stream {"record": {"text": "https://t.co/WOechJGkQH\u00a0\u00a0@eBay @youtube @Facebook @cnn @BBCBreaking @google @BBCWorld @twitter @cnnbrk @nytimes\u2026 https://t.co/8lPXzmQ00Y", "user": "@bestartart", "id": 1074760428486561792, "created_at": "Mon Dec 17 20:17:08 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:17:23,752 nuclio (D) writing data to Stream {"record": {"text": "RT @RepMattGaetz: ...but I would have been more encouraged if @Google would have acknowledged there is bias &amp; that they are taking actions\u2026", "user": "@JGonza28", "id": 1074760468995158016, "created_at": "Mon Dec 17 20:17:18 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 20:17:26,077 nuclio (D) writing data to Stream {"record": {"text": "Kudos to all the @google employees who stood up for doing the right thing over greed &amp; supporting totalitarian regi\u2026 https://t.co/KqNqb3FRdW", "user": "@abresler", "id": 1074760478663041024, "created_at": "Mon Dec 17 20:17:20 +0000 2018", "polarity": 0.26785714285714285, "subjectivity": 0.39285714285714285}}
# 2018-12-17 20:17:26,491 nuclio (D) writing data to Stream {"record": {"text": "@Liam_42953 @Mostafahmzd @LAWCABA @GOP @TheDemocrats @SenSchumer @JessicaV_CIS @GOPLeader @SpeakerRyan\u2026 https://t.co/OBmHH9ak7V", "user": "@lostcauseh1b", "id": 1074760480239939584, "created_at": "Mon Dec 17 20:17:21 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:17:36,285 nuclio (D) writing data to Stream {"record": {"text": "\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02@cnn @msnbc @maddow @CNNPolitics @ABCPolitics @ABC @CBSNews @NBCNews @CBSTweet @CBS @nbc @cnnbrk @TamronMSNBC\u2026 https://t.co/vTntUW8uE1", "user": "@SherryWall20", "id": 1074760521033900038, "created_at": "Mon Dec 17 20:17:30 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:17:45,187 nuclio (D) writing data to Stream {"record": {"text": "@tictoc @Google Where can I check for job postings at this campus?", "user": "@InkandMoxie", "id": 1074760558874951680, "created_at": "Mon Dec 17 20:17:39 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:18:03,584 nuclio (D) writing data to Stream {"record": {"text": "RT @PHCeoJM: #Energy Efficiency in Jamaica\u2019s Building Code -  #PHC #JAM @Google Slides https://t.co/1akfsicgIp", "user": "@PHCDigital", "id": 1074760636104671233, "created_at": "Mon Dec 17 20:17:58 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:18:09,425 nuclio (D) writing data to Stream {"record": {"text": "RT @Meliodaafu: @Seb_Frit @lemondefr Vous \u00eates des @Google \u00e0 faire \u00e7a", "user": "@Maellemerigot", "id": 1074760660561604609, "created_at": "Mon Dec 17 20:18:04 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:18:14,064 nuclio (D) writing data to Stream {"record": {"text": "#NBAAllStar Voting 2019 presented by @Google, which is now the league\u2019s presenting #NBAAllStar Voting partner, will\u2026 https://t.co/NEk9LGmCsm", "user": "@SportsRoadhouse", "id": 1074760679360421891, "created_at": "Mon Dec 17 20:18:08 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:18:26,148 nuclio (D) writing data to Stream {"record": {"text": "@BBukeeB @SamHarrisOrg @Google @YouTube @facebook @Twitter Learn to not be a beta male.", "user": "@billtthatsme", "id": 1074760730635919361, "created_at": "Mon Dec 17 20:18:20 +0000 2018", "polarity": 0.0, "subjectivity": 0.1}}
# 2018-12-17 20:18:37,004 nuclio (D) writing data to Stream {"record": {"text": "\u2066@Google\u2069 : You Can Ignore Negative #SEO Threats https://t.co/q4yJVvNujg", "user": "@RBTewksbury", "id": 1074760776160763906, "created_at": "Mon Dec 17 20:18:31 +0000 2018", "polarity": -0.3, "subjectivity": 0.4}}
# 2018-12-17 20:19:02,391 nuclio (D) writing data to Stream {"record": {"text": "RT @GoogleForEdu: Book Creator is now an official #GoogleEdu partner. Check out the magical ways @Google apps can work with @BookCreatorApp\u2026", "user": "@alisalinaELE", "id": 1074760882725498893, "created_at": "Mon Dec 17 20:18:57 +0000 2018", "polarity": 0.5, "subjectivity": 1.0}}
# 2018-12-17 20:19:07,726 nuclio (D) writing data to Stream {"record": {"text": "#BuildTheWall !! @cnn @msnbc @maddow @CNNPolitics @ABCPolitics @ABC @CBSNews @NBCNews @CBSTweet @CBS @nbc @cnnbrk\u2026 https://t.co/8XT0bgnMuT", "user": "@SherryWall20", "id": 1074760904791785475, "created_at": "Mon Dec 17 20:19:02 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:19:14,795 nuclio (D) writing data to Stream {"record": {"text": "@realDonaldTrump I'm just glad hundreds of pictures of me don't show up on @Google when anyone runs a search on the word \"#idiot\".", "user": "@RutherfordRocks", "id": 1074760934873317377, "created_at": "Mon Dec 17 20:19:09 +0000 2018", "polarity": -0.15000000000000002, "subjectivity": 0.9}}
# 2018-12-17 20:19:16,205 nuclio (D) writing data to Stream {"record": {"text": "https://t.co/XuUZP3I97M\u00a0\u00a0@eBay @youtube @Facebook @cnn @BBCBreaking @google @BBCWorld @twitter @cnnbrk @nytimes\u2026 https://t.co/xcyjSyOcpo", "user": "@ira76749839", "id": 1074760939688390657, "created_at": "Mon Dec 17 20:19:10 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:19:33,050 nuclio (D) writing data to Stream {"record": {"text": "\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02@cnn @msnbc @maddow @CNNPolitics @ABCPolitics @ABC @CBSNews @NBCNews @CBSTweet @CBS @nbc @cnnbrk @TamronMSNBC\u2026 https://t.co/fNDVz5dG6e", "user": "@SherryWall20", "id": 1074761010714681344, "created_at": "Mon Dec 17 20:19:27 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:19:33,878 nuclio (D) writing data to Stream {"record": {"text": "The Future Is Looking Bright. @googlecloud @Google \n\ud83c\udf0f\ud83c\udf0e\ud83c\udf0e https://t.co/FrXMzK75O9", "user": "@TierreWright", "id": 1074761013617180673, "created_at": "Mon Dec 17 20:19:28 +0000 2018", "polarity": 0.35000000000000003, "subjectivity": 0.46249999999999997}}
# 2018-12-17 20:19:34,314 nuclio (D) writing data to Stream {"record": {"text": "Dear @tomperez -- @DNC would be better attacking @GOP selling voter data to the Kochs than matching their actions.\u2026 https://t.co/P8aTvxyUhO", "user": "@shava23", "id": 1074761016406409217, "created_at": "Mon Dec 17 20:19:29 +0000 2018", "polarity": 0.5, "subjectivity": 0.5}}
# 2018-12-17 20:19:34,526 nuclio (D) writing data to Stream {"record": {"text": "RT @swedishousemfia: .@Google @Google @Google #YearInSearch https://t.co/v3H9YJpKUF", "user": "@DjGlobalByte", "id": 1074761017547284480, "created_at": "Mon Dec 17 20:19:29 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:19:37,227 nuclio (D) writing data to Stream {"record": {"text": "RT @loscarnaless: Hola (#TripAdvisor @TripAdvisor - @TripAdvisorES):\n\nAqu\u00ed le dejo un v\u00eddeo a @Google para que pueda indexarlo y todo el mu\u2026", "user": "@oitala_ella", "id": 1074761028695658497, "created_at": "Mon Dec 17 20:19:31 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:19:37,429 nuclio (D) writing data to Stream {"record": {"text": "@aMichelazzi @Google Have you been shooting handheld or with tripod? I makes quite a difference in the end result", "user": "@franzfifty", "id": 1074761029442330624, "created_at": "Mon Dec 17 20:19:32 +0000 2018", "polarity": 0.0, "subjectivity": 0.0}}
# 2018-12-17 20:19:39,224 nuclio (D) writing data to Stream {"record": {"text": "Absolutely", "user": "@charlidtoms", "id": 1074761037029826560, "created_at": "Mon Dec 17 20:19:33 +0000 2018", "polarity": 0.2, "subjectivity": 0.9}}
